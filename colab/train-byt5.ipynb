# %% [markdown]
# # Train T5 for ocr postcorrection
#
# Sources
# * https://huggingface.co/docs/transformers/tasks/summarization

# %% [markdown]
# ## Data
#
# * In: sequence with ocr errors
# * Out: sequence without ocr errors
# * Task prefix: `correct: `
#     * Not sure this is necessary...

# %%
from google.colab import drive
drive.mount('/mntDrive')

# %%
! git clone https://github.com/jvdzwaan/ocrpostcorrection-notebooks.git

# %%
# %cd /content/ocrpostcorrection-notebooks

# %%
! git checkout mT5-experiment

# %%
! pip install poetry

# %%
# Configure poetry to create virtual environments in the project folder
! poetry config virtualenvs.in-project true

# %%
! poetry install --no-ansi

# %%
# Add poetry virtual environment to python path so that all installed dependencies can be found by the python interpreter

import sys
sys.path.append("/content/ocrpostcorrection-notebooks/.venv/lib/python3.10/site-packages")

# %%
! cp /mntDrive/MyDrive/ocrpostcorrection-config/config.local .dvc/config.local

# %%
! poetry run dvc pull -r gdrive

# %%
! poetry run dvc checkout

# %%
from pathlib import Path

import pandas as pd
from datasets import Dataset, DatasetDict
from loguru import logger
from ocrpostcorrection.icdar_data import get_intermediate_data

# %%
# local
raw_dataset = Path('..')/'data'/'raw'/'ICDAR2019_POCR_competition_dataset.zip'

train_split = Path('..')/'data'/'splits'/'train.csv'
val_split = Path('..')/'data'/'splits'/'val.csv'
test_split = Path('..')/'data'/'splits'/'test.csv'

# %%
# colab
raw_dataset = Path('data')/'raw'/'ICDAR2019_POCR_competition_dataset.zip'

train_split = Path('data')/'splits'/'train.csv'
val_split = Path('data')/'splits'/'val.csv'
test_split = Path('data')/'splits'/'test.csv'

# %%
data, _, data_test, _ = get_intermediate_data(raw_dataset)
# Out:
# 10it [00:18,  1.85s/it]
# 10it [00:04,  2.02it/s]

# %%
X_train = pd.read_csv(train_split, index_col=0)
X_val = pd.read_csv(val_split, index_col=0)
X_test = pd.read_csv(test_split, index_col=0)

# %%
from typing import List, Dict, Tuple
from tqdm.notebook import tqdm

import edlib
from ocrpostcorrection.icdar_data import window, normalized_ed, Text


def _process_sequence(
    key: str,
    i: int,
    res,
    ocr_sents: List[str],
    gs_sents: List[str],
    keys: List[str],
    start_tokens: List[int],
    scores: List[float],
    languages: List[str],
) -> Tuple[
    List[str], List[str], List[str], List[int], List[float], List[str]
]:
    ocr = [t.ocr for t in res]
    gs = []
    for t in res:
        if t.gs != "":
            gs.append(t.gs)
    ocr_str = " ".join(ocr)
    gs_str = " ".join(gs)
    ed = edlib.align(ocr_str, gs_str)["editDistance"]
    score = normalized_ed(ed, ocr_str, gs_str)

    if len(ocr_str) > 0 and len(gs_str) > 0:
        ocr_sents.append(ocr_str)
        gs_sents.append(gs_str)
        keys.append(key)
        start_tokens.append(i)
        scores.append(score)
        languages.append(key[:2])
    else:
        logger.info(f'Empty sample for text "{key}"')
        logger.info(f"ocr_str: {ocr_str}")
        logger.info(f"gs_str: {gs_str}")
        logger.info(f"start token: {i}")

    return (ocr_sents, gs_sents, keys, start_tokens, scores, languages)


def generate_sentences(
    df: pd.DataFrame, data: Dict[str, Text], size: int = 15, step: int = 10
) -> pd.DataFrame:
    """Generate sequences of a certain length and possible overlap"""
    ocr_sents: List[str] = []
    gs_sents: List[str] = []
    keys: List[str] = []
    start_tokens: List[int] = []
    scores: List[float] = []
    languages: List[str] = []

    for _, row in tqdm(df.iterrows()):
        key = row.file_name
        tokens = data[key].input_tokens

        # print(len(tokens))
        # print(key)
        for i, res in enumerate(window(tokens, size=size)):
            if i % step == 0:
                (
                    ocr_sents,
                    gs_sents,
                    keys,
                    start_tokens,
                    scores,
                    languages,
                ) = _process_sequence(
                    key, i, res, ocr_sents, gs_sents, keys, start_tokens, scores, languages
                )
        # Add final sequence
        (ocr_sents, gs_sents, keys, start_tokens, scores, languages) = _process_sequence(
            key, i, res, ocr_sents, gs_sents, keys, start_tokens, scores, languages
        )

    output = pd.DataFrame(
        {
            "key": keys,
            "start_token_id": start_tokens,
            "score": scores,
            "ocr": ocr_sents,
            "gs": gs_sents,
            "language": languages,
        }
    )

    # Adding the final sequence may lead to duplicate rows. Remove those
    output.drop_duplicates(
        subset=["key", "start_token_id"], keep="first", inplace=True, ignore_index=True
    )

    return output

# %%
size = 25
step = 25

# %%
logger.info(f"Generating sentences (size: {size}, step: {step})")

train_data = generate_sentences(X_train, data, size=size, step=step)
val_data = generate_sentences(X_val, data, size=size, step=step)
test_data = generate_sentences(X_test, data_test, size=size, step=size)

num_train = train_data.shape[0]
num_val = val_data.shape[0]
num_test = test_data.shape[0]
logger.info(f"# samples train: {num_train}, val: {num_val}, test: {num_test})")
# Out:
# 2023-12-24 20:13:28.993 | INFO     | __main__:<module>:1 - Generating sentences (size: 25, step: 25)
# 0it [00:00, ?it/s]
# 2023-12-24 20:13:29.025 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/883.txt"
# 2023-12-24 20:13:29.025 | INFO     | __main__:_process_sequence:40 - ocr_str: # mmm mm mm mm mm mm mm mm mm mm mm mm mm mm mmm mm mm mm mm mm mm mmm mm mm
# 2023-12-24 20:13:29.026 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.026 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.090 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.093 | INFO     | __main__:_process_sequence:40 - ocr_str: Philippus naces lit regie dengnitatis, chemencam e ilionlibenter extenimus et seiu eorum liberali promonemus affectu, qui not serviciorm exnbicine grata pervenint et virtutum comis suffragis,
# 2023-12-24 20:13:29.096 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.098 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.100 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.100 | INFO     | __main__:_process_sequence:40 - ocr_str: digne sibi venditant primia mentorum. Nomnacaque facimus aniversi, tam presentibus quad futuris, pro lict Jihes Guibti, clericus et Guillelmus ejus fratis, corhibitis cipulis de Conjignes,
# 2023-12-24 20:13:29.102 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.102 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:29.102 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.103 | INFO     | __main__:_process_sequence:40 - ocr_str: vides et solutis extum habuisse dicantur. Nos, attendentos quod, sicut relacio fide digna testitur ipsi ad prtorum imittanda vestigia ferventer intenti sint sio affinrunt ubtate
# 2023-12-24 20:13:29.104 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.106 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.109 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.111 | INFO     | __main__:_process_sequence:40 - ocr_str: virtutumquod hujusmodi crenitur Maculami, sic eoram probitatu decore abstergit, ut eos à tol attalli favoribus graciosis debitum reputenis ac propter ea et intuitu dicti servici
# 2023-12-24 20:13:29.112 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.112 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:29.113 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.113 | INFO     | __main__:_process_sequence:40 - ocr_str: nobis impensi suis supplicacionibus annentes de certa sciencia et speciali gracia ac plenitudine regie potestatis predicte Johannem et Guillem de Copulis, predictis genitor ad honores
# 2023-12-24 20:13:29.113 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.114 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:29.115 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.118 | INFO     | __main__:_process_sequence:40 - ocr_str: solares actusque legitimos queslibet, quo ad tempalia tenendam, tenore presencium legittumitatis ticulo decorania hujusmodi geniture Mailam, quo ad premissa penitus abelenes et concedentes eisdem, ec
# 2023-12-24 20:13:29.120 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.123 | INFO     | __main__:_process_sequence:42 - start token: 125
# 2023-12-24 20:13:29.132 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.139 | INFO     | __main__:_process_sequence:40 - ocr_str: cordem alteri ut cum eis et eorum quolibet, tenore presenciu dispensantes de sciencia, po testate et auctoritate predcis, ut ipsi canque leguatum sucdere valeant et
# 2023-12-24 20:13:29.146 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.154 | INFO     | __main__:_process_sequence:42 - start token: 150
# 2023-12-24 20:13:29.155 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.155 | INFO     | __main__:_process_sequence:40 - ocr_str: suadant persons quibuscunque in bonis omnibus temporalibus, orobilibus et immobilibus, nabilibus et mobilibus, in quibus succendere ut de consuetudie vel de jure possent, si essent
# 2023-12-24 20:13:29.155 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.156 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-24 20:13:29.156 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.156 | INFO     | __main__:_process_sequence:40 - ocr_str: de legitimo matrimonis procreati, in quibus tam noisit jus alter vel alis, jam quesitum niesi et allos eis per justum titulum dimissum fuisset, et ea
# 2023-12-24 20:13:29.156 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.157 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:29.157 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.158 | INFO     | __main__:_process_sequence:40 - ocr_str: tanomn legutum valeant jure successeurbes vendicare adipisai retinere et jure hereditans paciffice, possidere et deppis dispone, tanquam successores seu heredit legitum in eisdem, dum tam
# 2023-12-24 20:13:29.160 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.162 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:29.165 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.166 | INFO     | __main__:_process_sequence:40 - ocr_str: aliid quam deffectus notalium predicts non repuguat deffectu hujusmi seu constitucone seatuts vel lege doict et consuetudine vel usu genarole vl localti regne nostri ad
# 2023-12-24 20:13:29.167 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.169 | INFO     | __main__:_process_sequence:42 - start token: 250
# 2023-12-24 20:13:29.170 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.170 | INFO     | __main__:_process_sequence:40 - ocr_str: hoc contrarie non obstantibus quibuscunque firmites inmngentes universis et singlis pnsttuatuis regni nostri, presentibus et futuris, ne quis cose et exorm quemliet aut perloni suam
# 2023-12-24 20:13:29.171 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.171 | INFO     | __main__:_process_sequence:42 - start token: 275
# 2023-12-24 20:13:29.171 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.171 | INFO     | __main__:_process_sequence:40 - ocr_str: vel heredes successoris aut posteros suos in bonis quibus cunque acquisitis et acquirendis seu videcique abvententibus, occaoine deffectus natalum predictos Johannem et Guillelmu ipetere Turlare
# 2023-12-24 20:13:29.172 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.172 | INFO     | __main__:_process_sequence:42 - start token: 300
# 2023-12-24 20:13:29.172 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.172 | INFO     | __main__:_process_sequence:40 - ocr_str: su molestare quoquomode presumat, et que corum merita permentur, ut nsoe gracia et benivolencia, am lioribus proseti debamus unde nnse et suis se fenciant honeratos,
# 2023-12-24 20:13:29.173 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.174 | INFO     | __main__:_process_sequence:42 - start token: 325
# 2023-12-24 20:13:29.174 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.174 | INFO     | __main__:_process_sequence:40 - ocr_str: ipsos et coreaquenibus de noreftate gracia et scienci supradictis nobilitamus et nobiles habiles facimus et reddimus, ut mlicie docrs cngulo valeant itlustrari, conte dentes eisdem
# 2023-12-24 20:13:29.175 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.176 | INFO     | __main__:_process_sequence:42 - start token: 350
# 2023-12-24 20:13:29.177 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.177 | INFO     | __main__:_process_sequence:40 - ocr_str: ut ipsi et cosam quibus cum omni sua posteritate, tam prcuata qum pertuanda in universis sinolis, actibus, tes possessionbs personis et bonis suis nobilitare possunt
# 2023-12-24 20:13:29.178 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.178 | INFO     | __main__:_process_sequence:42 - start token: 375
# 2023-12-24 20:13:29.179 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-24 20:13:29.180 | INFO     | __main__:_process_sequence:40 - ocr_str: quibus cum omni sua posteritate, tam prcuata qum pertuanda in universis sinolis, actibus, tes possessionbs personis et bonis suis nobilitare possunt et quacunque nobilitati pre
# 2023-12-24 20:13:29.180 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.180 | INFO     | __main__:_process_sequence:42 - start token: 379
# 2023-12-24 20:13:29.198 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/129.txt"
# 2023-12-24 20:13:29.199 | INFO     | __main__:_process_sequence:40 - ocr_str: i mm ### a, mm mm mm mm mm mm mm mm mm mm mm mm rnmm mm m* mmm mm mm mm mm mm
# 2023-12-24 20:13:29.199 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.199 | INFO     | __main__:_process_sequence:42 - start token: 150
# 2023-12-24 20:13:29.290 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/97.txt"
# 2023-12-24 20:13:29.291 | INFO     | __main__:_process_sequence:40 - ocr_str: obdeloval, ino pa vinograd zasadil. Ker vina moči še ni poznal, ga je pervič preveč pil. Upi jani se, ino nespodobno razodet leži v šotoru.
# 2023-12-24 20:13:29.291 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.291 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:29.292 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/97.txt"
# 2023-12-24 20:13:29.292 | INFO     | __main__:_process_sequence:40 - ocr_str: še ni poznal, ga je pervič preveč pil. Upi jani se, ino nespodobno razodet leži v šotoru. Kam, Noetov sin, vidi očeta ondi ležati, ino
# 2023-12-24 20:13:29.292 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.293 | INFO     | __main__:_process_sequence:42 - start token: 233
# 2023-12-24 20:13:29.305 | INFO     | __main__:_process_sequence:39 - Empty sample for text "DE/DE2/87.txt"
# 2023-12-24 20:13:29.305 | INFO     | __main__:_process_sequence:40 - ocr_str: fielen, also auch bei ©omttagSrulje 72 ©tunben in ber SEBocpe arbeiten, bie Kräfte bei ber Art ber Arbeit allzusehr auSgenupt mürben«. Sei ber üün ilpn
# 2023-12-24 20:13:29.305 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.305 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:29.306 | INFO     | __main__:_process_sequence:39 - Empty sample for text "DE/DE2/87.txt"
# 2023-12-24 20:13:29.306 | INFO     | __main__:_process_sequence:40 - ocr_str: getroffenen (Einrichtung arbeite bie I. Abtheilung 7 ©deichten ju 8 ©tunben = 56 ©tunben II. » 6 » ju 8 » = 48 » m.
# 2023-12-24 20:13:29.306 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.307 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.307 | INFO     | __main__:_process_sequence:39 - Empty sample for text "DE/DE2/87.txt"
# 2023-12-24 20:13:29.308 | INFO     | __main__:_process_sequence:40 - ocr_str: * 6 » ■ ju 8 > + 2 = 50 > also jede Abtheilung öl 1 ^ ©tunben durchschnittlich in ber SEBocpe. Am ©onntag
# 2023-12-24 20:13:29.308 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.309 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:29.369 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/31.txt"
# 2023-12-24 20:13:29.370 | INFO     | __main__:_process_sequence:40 - ocr_str: dus. Severus. Ambr. Mor. hb. 8. cap. I. Los unos y los otros valientes , y mili diestros y aparejados, con un riguroso corage ,
# 2023-12-24 20:13:29.370 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.370 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:29.473 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.474 | INFO     | __main__:_process_sequence:40 - ocr_str: LXXXXVI Sant. Ter. Camin. Sant. Ter. en su Vid. Sant. Ter. Exclam» Sant. Ter. Mor. Sartol. P.Suarez. Siguenz. Vid. de S.Geron. Silv. Hiil.de Don Florisél.
# 2023-12-24 20:13:29.474 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.474 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.475 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.475 | INFO     | __main__:_process_sequence:40 - ocr_str: Toled. Vicios. Torija , Trat. debov. Tortol, el Entreten. Torr. Hist. de los Xérif. Tose. 1 o^ost. Quest. Tost. sob. Euscb. Ulloa , Psalm. Valdecebr.
# 2023-12-24 20:13:29.475 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.475 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.476 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.476 | INFO     | __main__:_process_sequence:40 - ocr_str: de avés. Valer.de las Hist. Valverd. Vid. de Christ. Varg. de la Gineta. Varg. Milic. Indian. Velasc. Orthograph. Velez de Guev. Com. ^ o—Velez, Pharmacop.
# 2023-12-24 20:13:29.476 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.476 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:29.477 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.478 | INFO     | __main__:_process_sequence:40 - ocr_str: Veneg. Agón. Vigo, Cirug. Villamed. Obr.Poéf. Villalob. Problem. Villavic. Mofch. Vision deleitas. Zam. Com. el Hcchiz. por fuerza. Zarat. ZuñiG. Ann. de Sev, t|® Zürit.
# 2023-12-24 20:13:29.478 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.478 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:29.479 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.479 | INFO     | __main__:_process_sequence:40 - ocr_str: Anual. Santa Teresa de Jesús: Camino de perfección; Santa Tereía de Jesús: en fu Vida. Santa Teresa de Jeíus: Exclamaciones. Santa Teresa de Jesús: Moradas.
# 2023-12-24 20:13:29.479 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.479 | INFO     | __main__:_process_sequence:42 - start token: 125
# 2023-12-24 20:13:29.480 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.480 | INFO     | __main__:_process_sequence:40 - ocr_str: Padre Bernardo Sartólo: Vida del Padre Suarez, Padre Frai Jofeph de Sigíienza: Vida de San Gerónymo, Feliciano de Silva: Historia de Don Florisél de Niquéa.
# 2023-12-24 20:13:29.480 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.481 | INFO     | __main__:_process_sequence:42 - start token: 150
# 2023-12-24 20:13:29.481 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.481 | INFO     | __main__:_process_sequence:40 - ocr_str: Miguel de Silveira: el Machabéo. El Soldado Píndaro: de Gonzalo de Cespedes. Jacobo Soler: Repertorio de las Leyes de Castilla. Don Antonio de Solís: Historia
# 2023-12-24 20:13:29.481 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.481 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-24 20:13:29.482 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.482 | INFO     | __main__:_process_sequence:40 - ocr_str: de Nueva España. Don Antonio de Solís: fus Obras Poéticas. Don Juan Suarez de Peralta: Doctrina de Caballos. Tarifa de la Aduana de Zaragoza. d:>
# 2023-12-24 20:13:29.482 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.482 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:29.483 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.483 | INFO     | __main__:_process_sequence:40 - ocr_str: I" I Bachiller Alphonso Martínez de Toledo: Vicios de las malas mu* geres. .. Juande Torija: Tratado de bóvedas. Antonio Sánchez Tortoles: el Entretenido. Diego
# 2023-12-24 20:13:29.483 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.484 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:29.484 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.484 | INFO     | __main__:_process_sequence:40 - ocr_str: de Torres: Historia de losXerifes. Padre Thomás Vicente Tosca: Compendio Mathematicbi Don Alonso Tostado : Questiones. Don Alonso Tostado : sobre Eusebio. Don Luis de
# 2023-12-24 20:13:29.494 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.505 | INFO     | __main__:_process_sequence:42 - start token: 250
# 2023-12-24 20:13:29.512 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.518 | INFO     | __main__:_process_sequence:40 - ocr_str: Ulloa: Psalmos penitenciales. Frai Andrés Ferrer de Valdecebro: de aves. Valerio de las Historias. Frai Fernando de Valverde: Vida de Christo. Bernardo de Vargas y
# 2023-12-24 20:13:29.519 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.519 | INFO     | __main__:_process_sequence:42 - start token: 275
# 2023-12-24 20:13:29.519 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.520 | INFO     | __main__:_process_sequence:40 - ocr_str: Machuca : de la Gineta. Bernardo de Vargas y Machuca: Milicia Indiana; Juan Lopez de Velasco: Orthographía Castellana^ Luis Velez de Guevara: fus Obras Cómicas.
# 2023-12-24 20:13:29.520 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.520 | INFO     | __main__:_process_sequence:42 - start token: 300
# 2023-12-24 20:13:29.520 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.521 | INFO     | __main__:_process_sequence:40 - ocr_str: Francisco Velez: Pharmacopéa. Alexo Venegas: Agonía de la muerte. Juan de Vigo: Cirugía. El Conde de Viliamediana: fus Obras Poéticas.; Doctor Francisco de Villalobos: Problemas.
# 2023-12-24 20:13:29.521 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.521 | INFO     | __main__:_process_sequence:42 - start token: 325
# 2023-12-24 20:13:29.522 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/34.txt"
# 2023-12-24 20:13:29.522 | INFO     | __main__:_process_sequence:40 - ocr_str: Don Jofeph de Villaviciofa: la Moschéa. Visión deleitable del Bachiller Alphonso de la Torrd. Don Antonio de Zamora: Comedia, el Hechizado por fuerza. Francisco Lopez
# 2023-12-24 20:13:29.522 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.522 | INFO     | __main__:_process_sequence:42 - start token: 350
# 2023-12-24 20:13:29.547 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/628.txt"
# 2023-12-24 20:13:29.548 | INFO     | __main__:_process_sequence:40 - ocr_str: deless majesté st trison envers nous pour coy tous ses biens meubles et heritages, en quelque lieu povoir et jurisdicion que il soient assiz en
# 2023-12-24 20:13:29.548 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.548 | INFO     | __main__:_process_sequence:42 - start token: 400
# 2023-12-24 20:13:29.549 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/628.txt"
# 2023-12-24 20:13:29.549 | INFO     | __main__:_process_sequence:40 - ocr_str: comme ler rertages pringne et tiegne en la main de nostre dit seigneur et ce fait en baillé de livre et assigné au dit Guirt
# 2023-12-24 20:13:29.550 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.550 | INFO     | __main__:_process_sequence:42 - start token: 600
# 2023-12-24 20:13:29.550 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/628.txt"
# 2023-12-24 20:13:29.551 | INFO     | __main__:_process_sequence:40 - ocr_str: ou à se procureur pour hoi ii. livres de terre ou rente comme dit est, et l'en mette ou son dit procureur pour li en
# 2023-12-24 20:13:29.551 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.551 | INFO     | __main__:_process_sequence:42 - start token: 625
# 2023-12-24 20:13:29.552 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/628.txt"
# 2023-12-24 20:13:29.552 | INFO     | __main__:_process_sequence:40 - ocr_str: bonne possession et saisine paisibles, selon la a tenu des lettres du reroy nostre dit seigneur et dest ces presentes, et l'en face et laisse
# 2023-12-24 20:13:29.552 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.552 | INFO     | __main__:_process_sequence:42 - start token: 650
# 2023-12-24 20:13:29.553 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/628.txt"
# 2023-12-24 20:13:29.553 | INFO     | __main__:_process_sequence:40 - ocr_str: joir et user paisiblement mandement et commandens à touz les justiciers et officiers du roy nostre sire et de mostre dit seigneur pions et requeons
# 2023-12-24 20:13:29.553 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.554 | INFO     | __main__:_process_sequence:42 - start token: 675
# 2023-12-24 20:13:29.554 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/628.txt"
# 2023-12-24 20:13:29.554 | INFO     | __main__:_process_sequence:40 - ocr_str: touz autres que en faisant les choses dessus dictes et chacune d'icelles obeissante et entondns diligemment et vous prestre conseil confort et aide tomest est
# 2023-12-24 20:13:29.555 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.555 | INFO     | __main__:_process_sequence:42 - start token: 700
# 2023-12-24 20:13:29.570 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/72.txt"
# 2023-12-24 20:13:29.571 | INFO     | __main__:_process_sequence:40 - ocr_str: Viene del Latino Solvens. Mart. Medie. Scept. part.2. Convers. 38. §.1. Debo supo ner, demás de esto, como acredita la expe riencia, que la saliva
# 2023-12-24 20:13:29.571 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.571 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:29.587 | INFO     | __main__:_process_sequence:39 - Empty sample for text "CZ/CZ1/32.txt"
# 2023-12-24 20:13:29.587 | INFO     | __main__:_process_sequence:40 - ocr_str: ,>• / • - •' ■ >': - . ' . ‘ -V - . .4'.■■■ ří 1 .'-*• _ ** -vy • -Jí ií*j
# 2023-12-24 20:13:29.588 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.588 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.588 | INFO     | __main__:_process_sequence:39 - Empty sample for text "CZ/CZ1/32.txt"
# 2023-12-24 20:13:29.588 | INFO     | __main__:_process_sequence:40 - ocr_str: f. - f- i ,-j ■' 1 . ■ -» >. . ■- •. . '■■■■.í í •|?ř .< ■. -»>:!- ijts...- * ' ■/
# 2023-12-24 20:13:29.589 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.589 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:29.589 | INFO     | __main__:_process_sequence:39 - Empty sample for text "CZ/CZ1/32.txt"
# 2023-12-24 20:13:29.589 | INFO     | __main__:_process_sequence:40 - ocr_str: ■ ■ s v*-.-.■■&(*■ ^ ' i • ''I' Vi!-.. , , ... . ■fy ■ ■ " '■ j>;,ý V ' . ' '
# 2023-12-24 20:13:29.590 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.590 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.590 | INFO     | __main__:_process_sequence:39 - Empty sample for text "CZ/CZ1/32.txt"
# 2023-12-24 20:13:29.590 | INFO     | __main__:_process_sequence:40 - ocr_str: s v*-.-.■■&(*■ ^ ' i • ''I' Vi!-.. , , ... . ■fy ■ ■ " '■ j>;,ý V ' . ' ' ^ ’
# 2023-12-24 20:13:29.591 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.591 | INFO     | __main__:_process_sequence:42 - start token: 52
# 2023-12-24 20:13:29.634 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/1060.txt"
# 2023-12-24 20:13:29.635 | INFO     | __main__:_process_sequence:40 - ocr_str: « ,#* mm u,* mmn Km* w i%a m m* aii* rrm * imac a* *** \mm am* mm ** ■** /me mm, s* *a&
# 2023-12-24 20:13:29.635 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.635 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.636 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/1060.txt"
# 2023-12-24 20:13:29.636 | INFO     | __main__:_process_sequence:40 - ocr_str: iaa» w# «n*i %** ma «va m w '* **x n&a *». u, mm a*, *■ ;■* &* ##■ mm *a# «■# «m nm xmm
# 2023-12-24 20:13:29.636 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.636 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:29.637 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/1060.txt"
# 2023-12-24 20:13:29.637 | INFO     | __main__:_process_sequence:40 - ocr_str: mm* mm w# ta*, un .* ,aa «a* #*r .t/ .1* n. ..mw \jm wm *1 m * ma* w «#i kjm *** "a* *
# 2023-12-24 20:13:29.637 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.637 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:29.658 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/561.txt"
# 2023-12-24 20:13:29.659 | INFO     | __main__:_process_sequence:40 - ocr_str: mm mx* ■*&. w *#* mar mm mm mm mm mm w* um mm ma. mm ,uj sum mm tmm mm mm mm mm *
# 2023-12-24 20:13:29.660 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.660 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.660 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/561.txt"
# 2023-12-24 20:13:29.661 | INFO     | __main__:_process_sequence:40 - ocr_str: mm wmj an amr w# *** w* ** mm mm mm mm me mm mm mm mmm mm m&, «w mm imm #, mu* mmi
# 2023-12-24 20:13:29.661 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.661 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:29.669 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/130.txt"
# 2023-12-24 20:13:29.669 | INFO     | __main__:_process_sequence:40 - ocr_str: I _____ I Cl E NCT A -a 9 OZK ACH 4' kamienny poflument. t ciwoth tylko był formowany matcryi, 1 kamienia y drzewa pewnego;
# 2023-12-24 20:13:29.669 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.669 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.678 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/313.txt"
# 2023-12-24 20:13:29.678 | INFO     | __main__:_process_sequence:40 - ocr_str: en biens sont où estoient pour ce prins, saisiz arrestez ou empeschez mectes les le ou faites mettre tamps e sans delay à plaine delivrance.
# 2023-12-24 20:13:29.678 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.678 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.693 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/293.txt"
# 2023-12-24 20:13:29.693 | INFO     | __main__:_process_sequence:40 - ocr_str: Donu factum habitatoribus ville de Angulis, et certe plates situate juxta ecclesiam dicte ville per civitio faciendo, cum dono dugiidi et trium Pictarim pro dicta
# 2023-12-24 20:13:29.694 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.694 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.731 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/14.txt"
# 2023-12-24 20:13:29.732 | INFO     | __main__:_process_sequence:40 - ocr_str: ■
# 2023-12-24 20:13:29.732 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.732 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.732 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/14.txt"
# 2023-12-24 20:13:29.733 | INFO     | __main__:_process_sequence:40 - ocr_str: ■
# 2023-12-24 20:13:29.733 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.733 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.811 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.813 | INFO     | __main__:_process_sequence:40 - ocr_str: *m rjmm tmm rntm mm* ** «w< mm ** * a* *am mm* ama mm mmm mm mm: m.% mm mm. * mm «ma w*
# 2023-12-24 20:13:29.818 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.819 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.819 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.820 | INFO     | __main__:_process_sequence:40 - ocr_str: #m *** un ,m#a -mm waa; mm mm mm '*# mu mm »## mm mm mw# em* w#i ## &## maa aaaa ■■# w* mw,
# 2023-12-24 20:13:29.820 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.820 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:29.821 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.821 | INFO     | __main__:_process_sequence:40 - ocr_str: ### wm am mm mm mm mm ms* mm awn w% wr mmc umm tmm mm mmm tmm mm» mtm mm ama ymn mrnv *****
# 2023-12-24 20:13:29.821 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.821 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:29.822 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.822 | INFO     | __main__:_process_sequence:40 - ocr_str: tam mm mm mm mm .mm mm mm mm mmm .m* mm tmm <mu mm mm >mm tmm mm mmt mm mmm w ■## -mm
# 2023-12-24 20:13:29.822 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.824 | INFO     | __main__:_process_sequence:42 - start token: 125
# 2023-12-24 20:13:29.835 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.836 | INFO     | __main__:_process_sequence:40 - ocr_str: i#, #*# %ma aw %w a# w r#a ##* a# aww u# ——• tmm mm yu #ra# «a m# wx ##i #*w #*# >wto awa
# 2023-12-24 20:13:29.837 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.837 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-24 20:13:29.837 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.838 | INFO     | __main__:_process_sequence:40 - ocr_str: y## mr% au* amar #a ** * ** mw w* mm mm mm marna ## maaa mm a# au *w aw maa mw *# #■'
# 2023-12-24 20:13:29.839 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.841 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:29.841 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-24 20:13:29.842 | INFO     | __main__:_process_sequence:40 - ocr_str: aw «a* mw ma# w &a# m ma# a#, ma *a mm mm aw a# %m mrm mm mm# #f, a## ma* ma# m# ma
# 2023-12-24 20:13:29.843 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.843 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:29.856 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/123.txt"
# 2023-12-24 20:13:29.857 | INFO     | __main__:_process_sequence:40 - ocr_str: popiše! Kako obilen Studenic čiste sreče nam odpre v našim lastnim sercu! Tak naj bo kdo, tako odvezen od pozemeljskiga, tako iz serca po nižen,
# 2023-12-24 20:13:29.857 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.858 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:29.858 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/123.txt"
# 2023-12-24 20:13:29.858 | INFO     | __main__:_process_sequence:40 - ocr_str: serca po nižen, tako tih ino poterpežljiv vterpljenji, tako pohleven ino krotak, tako vnet za vse dobro, tako mil ino usmiljen, tako nedolžen brez ovin-
# 2023-12-24 20:13:29.859 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.859 | INFO     | __main__:_process_sequence:42 - start token: 247
# 2023-12-24 20:13:29.896 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/120.txt"
# 2023-12-24 20:13:29.896 | INFO     | __main__:_process_sequence:40 - ocr_str: t r'""\ i r
# 2023-12-24 20:13:29.897 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.897 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.897 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/120.txt"
# 2023-12-24 20:13:29.897 | INFO     | __main__:_process_sequence:40 - ocr_str: t r'""\ i r
# 2023-12-24 20:13:29.898 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.899 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.923 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/178.txt"
# 2023-12-24 20:13:29.924 | INFO     | __main__:_process_sequence:40 - ocr_str: # mm mmm ■# ## mm mm mm mm mm mm mm mm mm mm mm mm mm mm» mm mm mm mm mmm mmm
# 2023-12-24 20:13:29.924 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.925 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:29.948 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/80.txt"
# 2023-12-24 20:13:29.949 | INFO     | __main__:_process_sequence:40 - ocr_str: r
# 2023-12-24 20:13:29.949 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.949 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.949 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/80.txt"
# 2023-12-24 20:13:29.950 | INFO     | __main__:_process_sequence:40 - ocr_str: r
# 2023-12-24 20:13:29.950 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.950 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:29.979 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/711.txt"
# 2023-12-24 20:13:29.979 | INFO     | __main__:_process_sequence:40 - ocr_str: *** az *n$ ** *** im im u*, «ma ma* «ma mm &?%% i*a «mu msm mm* m ma ** *m# #w *',****•**•**$******** ********* ma*
# 2023-12-24 20:13:29.980 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:29.980 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:30.001 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/60.txt"
# 2023-12-24 20:13:30.001 | INFO     | __main__:_process_sequence:40 - ocr_str: mu wm m* #** »«* v* rmn w* mm mm mm mm mm «me m# ww w* *■" mw * mm mm #u «ma au
# 2023-12-24 20:13:30.001 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.002 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:30.031 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/72.txt"
# 2023-12-24 20:13:30.031 | INFO     | __main__:_process_sequence:40 - ocr_str: precisely at Seven. (£3- The BOX-OFFICE will be Opened Daily, from Ten until Four, under the Superintendance of Mr. BUCKE, of wham Places and Private
# 2023-12-24 20:13:30.031 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.031 | INFO     | __main__:_process_sequence:42 - start token: 500
# 2023-12-24 20:13:30.032 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/72.txt"
# 2023-12-24 20:13:30.032 | INFO     | __main__:_process_sequence:40 - ocr_str: Boxes may be taken. For the greater accommodation of the Public, Places may be taken from Four till Six o’Clock, at No. 4, Little Russell
# 2023-12-24 20:13:30.032 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.033 | INFO     | __main__:_process_sequence:42 - start token: 525
# 2023-12-24 20:13:30.033 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/72.txt"
# 2023-12-24 20:13:30.033 | INFO     | __main__:_process_sequence:40 - ocr_str: Russell Street, facing the Stage Entrance. VIVAN T REX ET REGINA. No Money lo be returned J. Tibby,” Prioter, Tbe.tr* Roy. 1 , Dr.ij Las*.
# 2023-12-24 20:13:30.034 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.034 | INFO     | __main__:_process_sequence:42 - start token: 549
# 2023-12-24 20:13:30.046 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/15.txt"
# 2023-12-24 20:13:30.049 | INFO     | __main__:_process_sequence:40 - ocr_str: so šle z njim v hišo k ženitnini, ino duri se zapro. Pozneje pridejo tudi une device, ino kličejo: „Gospod, odpri nam,.odpri!" Že nin pa
# 2023-12-24 20:13:30.052 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.054 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:30.058 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/15.txt"
# 2023-12-24 20:13:30.066 | INFO     | __main__:_process_sequence:40 - ocr_str: je odgovoril: „ Gotovo, vam povem, ne poznam vas?" Cimu so svetila brez olja? Kaj pomagajo zunanje dobre dela brez svetiga konca, brez dobriga serca?
# 2023-12-24 20:13:30.074 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.075 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:30.096 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/73.txt"
# 2023-12-24 20:13:30.096 | INFO     | __main__:_process_sequence:40 - ocr_str: tens. Quar. f. 14. Contra un uracán , 6 torbellino espantoso , que no solo os mue ve los tcjaroces fino que los cimientos os
# 2023-12-24 20:13:30.096 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.097 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:30.100 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/603.txt"
# 2023-12-24 20:13:30.101 | INFO     | __main__:_process_sequence:40 - ocr_str: de Fano clerico et senescall li Item sumilis agistro Johanni de Laiceno et senescallo igus et matiscu, ac Bertholomes, captri cuni lugetr ac panetano Doni
# 2023-12-24 20:13:30.101 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.101 | INFO     | __main__:_process_sequence:42 - start token: 700
# 2023-12-24 20:13:30.102 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/603.txt"
# 2023-12-24 20:13:30.102 | INFO     | __main__:_process_sequence:40 - ocr_str: Fano clerico et senescall li Item sumilis agistro Johanni de Laiceno et senescallo igus et matiscu, ac Bertholomes, captri cuni lugetr ac panetano Doni te
# 2023-12-24 20:13:30.103 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.103 | INFO     | __main__:_process_sequence:42 - start token: 701
# 2023-12-24 20:13:30.110 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/70.txt"
# 2023-12-24 20:13:30.111 | INFO     | __main__:_process_sequence:40 - ocr_str: I '*!*<» i s ! «8 3» «í ££ •8 ® «*® a afr «8 84 «8 ^ *8 *, ¿>£ «8 € ^ «8
# 2023-12-24 20:13:30.111 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.111 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:30.112 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/70.txt"
# 2023-12-24 20:13:30.112 | INFO     | __main__:_process_sequence:40 - ocr_str: «g $* «g ag «g $ «g a #« tfó *• «g $* S «s* 3¿ «i a*» «g &** «g &* «g &*> «gr
# 2023-12-24 20:13:30.113 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.113 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:30.114 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/70.txt"
# 2023-12-24 20:13:30.114 | INFO     | __main__:_process_sequence:40 - ocr_str: ^ &*» se ® 04 3* s $* 25 i #* n v g* «g 38* «gr«« «g & ^ «g a &* «g *
# 2023-12-24 20:13:30.114 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.115 | INFO     | __main__:_process_sequence:42 - start token: 250
# 2023-12-24 20:13:30.115 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/70.txt"
# 2023-12-24 20:13:30.115 | INFO     | __main__:_process_sequence:40 - ocr_str: &s* fg 38* «g «* &3ii «g $K «g ^ 2S *• -a* H v3* I # i «g £•» «g « ^ «g S'
# 2023-12-24 20:13:30.115 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.116 | INFO     | __main__:_process_sequence:42 - start token: 275
# 2023-12-24 20:13:30.130 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/312.txt"
# 2023-12-24 20:13:30.131 | INFO     | __main__:_process_sequence:40 - ocr_str: et à tous autres. Si donnons en mandement par cesdictes presentes  à nostre seneschal de Poictou et à tous noz jestics ou à leurs
# 2023-12-24 20:13:30.131 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.131 | INFO     | __main__:_process_sequence:42 - start token: 324
# 2023-12-24 20:13:30.142 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/85.txt"
# 2023-12-24 20:13:30.143 | INFO     | __main__:_process_sequence:40 - ocr_str: 1 FV iT P.EX. No Money to be returns 4. J la'by, 4V'nttr,Theatre Royal. Ornry La-ne To-morrow, THURSDAY, April 15, 1830, 11 is VJajcs(js T
# 2023-12-24 20:13:30.143 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.143 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:30.145 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/85.txt"
# 2023-12-24 20:13:30.146 | INFO     | __main__:_process_sequence:40 - ocr_str: opened D.ilv, under il.e Supeiintendence of Mr. OH ARI ES WRIGHT, of who« PLACES and -PRIVATE BOXES may b * taker, from Ten till Four.
# 2023-12-24 20:13:30.146 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.146 | INFO     | __main__:_process_sequence:42 - start token: 431
# 2023-12-24 20:13:30.184 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.184 | INFO     | __main__:_process_sequence:40 - ocr_str: - • Man;ll>'S Rcx J idaitus, * Jechcims Rex judarus, Jojnnci, ■ Emanuel, - Carolus Magnur* - - Carolus Ctaffus, - Conradus primus, - -
# 2023-12-24 20:13:30.184 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.185 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:30.185 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.185 | INFO     | __main__:_process_sequence:40 - ocr_str: - Fridericus Auftrius, - 'Mgifmundus - - • Carolus Quintus, - - - - Rudólphus Sccundu* Imperator Rowiaaus, * . ... Morerius (Jlaiuny Autor ]
# 2023-12-24 20:13:30.186 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.186 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:30.186 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.187 | INFO     | __main__:_process_sequence:40 - ocr_str: Panis. - Bcrolinum, • • SuBineatnus, » Roma - Et & converfo Amor* - » D«vid es Rex, - - « - - Nicolaus, -
# 2023-12-24 20:13:30.187 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.188 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:30.188 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.188 | INFO     | __main__:_process_sequence:40 - ocr_str: » * Lubomirius Sranlslaui, ... Jjnulliuj koributh dc Wiśniowiec Omncs in Adam peccarrunt, -• Eta, - - Maria Magdalena, - - En 0:iva, * *
# 2023-12-24 20:13:30.188 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.189 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:30.189 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.189 | INFO     | __main__:_process_sequence:40 - ocr_str: ' - - Urfula, ... Ave MARIA, • ” GRATIA, PLENA - DOMIN Ui TtCUM, Amicu*. Caimus Lut cras. f>c nexa. Levis Amor, ^“J.Securas Anrmas
# 2023-12-24 20:13:30.190 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.190 | INFO     | __main__:_process_sequence:42 - start token: 125
# 2023-12-24 20:13:30.191 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.192 | INFO     | __main__:_process_sequence:40 - ocr_str: (eduxifti ?f ! Es vmdfx J hova 5’acrł En Jtf&n. * Ltvanien. Cumulins agro# L;ITj fucrurras, Mm purus candor Fidc currij, aflu r«is Mufi* dignua*
# 2023-12-24 20:13:30.192 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.193 | INFO     | __main__:_process_sequence:42 - start token: 150
# 2023-12-24 20:13:30.193 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.193 | INFO     | __main__:_process_sequence:40 - ocr_str: ^ Quin daru*, nctus. ^ Rcćłar humanui O' Purus, Deis par, Ore mirus, 'Spina. <T> er, <o O* -1 3 Mundo Sol . 2 >
# 2023-12-24 20:13:30.194 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.194 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-24 20:13:30.195 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/71.txt"
# 2023-12-24 20:13:30.196 | INFO     | __main__:_process_sequence:40 - ocr_str: H > Lumen orbi. Sus, tinea, mas, Amor, albo Mora* Roma. DEI Dux eras, Icon, L»us. Mirobulius TalTaHouj. JuflafllnusThyburok de Wiecfiwbo, En mater adfum, non
# 2023-12-24 20:13:30.196 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.196 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:30.272 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/135.txt"
# 2023-12-24 20:13:30.273 | INFO     | __main__:_process_sequence:40 - ocr_str: De Y asna] (A) fueran (y) del N. al O. 6 $ 6 De Campanario {¿) Cosin (¿f 5 ) del N. al E. 60
# 2023-12-24 20:13:30.273 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:30.274 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:30.321 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/132.txt"
# 2023-12-24 20:13:30.322 | INFO     | __main__:_process_sequence:40 - ocr_str: L O B bo: y estoi determinado de no creeros mas,' ni dexar pallar la burla adelante. Del lobo un pelo, y este de la
# 2023-12-24 20:13:30.322 | INFO     | __main__:_process_sequence:41 - gs_str:
# ...
# 2023-12-24 20:13:40.858 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.858 | INFO     | __main__:_process_sequence:42 - start token: 125
# 2023-12-24 20:13:40.859 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-24 20:13:40.859 | INFO     | __main__:_process_sequence:40 - ocr_str: Pokoleniom za lat 6>-y niewolę obiecuie- - ■ Rzym od Romulufa założony, - Tenże Rzym według Varrona inakfzey fupputacyi wzioł fwoie- fundamenta, Roku od Stworzenia
# 2023-12-24 20:13:40.859 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.860 | INFO     | __main__:_process_sequence:42 - start token: 150
# 2023-12-24 20:13:40.860 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-24 20:13:40.860 | INFO     | __main__:_process_sequence:40 - ocr_str: Świata 3251 dnia zi. Kwie tnia, przed Narodzeniem Pańfk'm 749 Jeruzalem od Chaldeyczykow wzięte, y Kroleflwo Judzkie lat .485 ftoiące, upadło. - - Septunginta Hbdomades
# 2023-12-24 20:13:40.861 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.861 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-24 20:13:40.861 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-24 20:13:40.861 | INFO     | __main__:_process_sequence:40 - ocr_str: Daniela Proroka nadały przed Chryftu- fem laty 453 albo według Drugich 553 Nie co infzego fą. tyl ko fiedmdziefiąt tygodni lat, alias 490 po których
# 2023-12-24 20:13:40.862 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.862 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:40.862 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-24 20:13:40.862 | INFO     | __main__:_process_sequence:40 - ocr_str: {kończo nych, obiecuie BOG Danielowi wyzwolenie Świata z Niewoli grzechu, śmierci, y cżarta, przez Meflyafza CHRYSTUSA, Et ungatur Sanflus, Sanćlot um; Danielis 9 Zdaie fię
# 2023-12-24 20:13:40.863 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.863 | INFO     | __main__:_process_sequence:42 - start token: 225
# 2023-12-24 20:13:40.863 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-24 20:13:40.864 | INFO     | __main__:_process_sequence:40 - ocr_str: Autorom, ie zaczęte te Hebdomades /{oku - « • Dom Boży który ftał lat 424 od Nabazwdy fpalony Taż Swiątnica Boża po wyściu z Niewoli
# 2023-12-24 20:13:40.864 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.864 | INFO     | __main__:_process_sequence:42 - start token: 250
# 2023-12-24 20:13:40.864 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-24 20:13:40.864 | INFO     | __main__:_process_sequence:40 - ocr_str: Izraelitów re/łaurowana- PLATO Filozof nazwany Divinus ) ( Tejte Kircbero) urodził fię. 2760. 2900. o 3 29 • K- C O a. tn rt «
# 2023-12-24 20:13:40.865 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.865 | INFO     | __main__:_process_sequence:42 - start token: 275
# 2023-12-24 20:13:40.866 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/45.txt"
# 2023-12-24 20:13:40.867 | INFO     | __main__:_process_sequence:40 - ocr_str: P O G A N $ KICH 9; JtgnuTti grahtitdinis. Inni hv Ii Bogowie Caleftes, albo Superh Inni Ter- reftres. Jednych zwano Wagms albo Majores
# 2023-12-24 20:13:40.867 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.867 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:40.883 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/1.txt"
# 2023-12-24 20:13:40.887 | INFO     | __main__:_process_sequence:40 - ocr_str: 1 1 28 1 banalhke l 27 1 -'9 1 v Turfhize . l 3 1 ti 1 t Sorrhize - l 8 I 1
# 2023-12-24 20:13:40.898 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.899 | INFO     | __main__:_process_sequence:42 - start token: 500
# 2023-12-24 20:13:40.899 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/1.txt"
# 2023-12-24 20:13:40.899 | INFO     | __main__:_process_sequence:40 - ocr_str: 2 1 v Ershi — 58 l 4 1 v Je/hmcna . ■— 53 1 — 1 Prola .... l 2 1 o 1 ii
# 2023-12-24 20:13:40.899 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.900 | INFO     | __main__:_process_sequence:42 - start token: 525
# 2023-12-24 20:13:40.917 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/18.txt"
# 2023-12-24 20:13:40.917 | INFO     | __main__:_process_sequence:40 - ocr_str: in streže je prišel, ki me je k njemu pripeljal in peljal me je, se mi vedno pripogovaje, v lepo stanico, pa kmalo se je
# 2023-12-24 20:13:40.917 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.917 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:40.920 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/21.txt"
# 2023-12-24 20:13:40.920 | INFO     | __main__:_process_sequence:40 - ocr_str: postave, celo glavo veči od vsih rojakov. — S perviga je bil cel vojšak ino pa ves dober j pa kraljeva čast ga je prevzetniga
# 2023-12-24 20:13:40.921 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.921 | INFO     | __main__:_process_sequence:42 - start token: 214
# 2023-12-24 20:13:40.926 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/29.txt"
# 2023-12-24 20:13:40.926 | INFO     | __main__:_process_sequence:40 - ocr_str: Sab ftojn. 4 Sha li ti. S$ le. J She lje. Si da nje. 4 Shi da na. So ba ti. J Shovsh nat. Sh
# 2023-12-24 20:13:40.927 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.927 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-24 20:13:40.927 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/29.txt"
# 2023-12-24 20:13:40.927 | INFO     | __main__:_process_sequence:40 - ocr_str: va nje. 4 Shu pa ni. t Sak fe bi. ■O JShav ba. jSer bg ti. 4' t Sh^ malt. t Si bo glavz. t
# 2023-12-24 20:13:40.927 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.928 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:40.928 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/29.txt"
# 2023-12-24 20:13:40.928 | INFO     | __main__:_process_sequence:40 - ocr_str: Sin kovz. t So fp tka. 4’ JSho iar ze. Suk ni za. 2 .Sh .n ta na. XXXXXX XXXXXX-«X xxxxxxxxx Ta ji tla. «•
# 2023-12-24 20:13:40.928 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.929 | INFO     | __main__:_process_sequence:42 - start token: 50
# 2023-12-24 20:13:40.929 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/29.txt"
# 2023-12-24 20:13:40.930 | INFO     | __main__:_process_sequence:40 - ocr_str: V’ be shim. Te lgf nu. 2 V’ di nu van je. Ti zhi za. ■š V’ do vam. To vor nik. V ja mefh.
# 2023-12-24 20:13:40.930 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.930 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:40.931 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/29.txt"
# 2023-12-24 20:13:40.931 | INFO     | __main__:_process_sequence:40 - ocr_str: Tu ti ka. q- Vu zhe noft. Vav pe tov. <*■ Wal bur ga. dom zi. J*. We ned k e. Vi ri jem. 4
# 2023-12-24 20:13:40.932 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.932 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:40.936 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.936 | INFO     | __main__:_process_sequence:40 - ocr_str: . Antimon . Antimonglanz Antimonit . Antbraeit . Antracit . Apatit .... Apnenec . Apno hidravlično Aquamarin Aragonec . Aragonit . Argentit . Arsenik Arsenikkies
# 2023-12-24 20:13:40.936 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.937 | INFO     | __main__:_process_sequence:42 - start token: 25
# 2023-12-24 20:13:40.937 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.937 | INFO     | __main__:_process_sequence:40 - ocr_str: Barit . 48 Bazalt . 88 Belec . 57 Bergholz . 55 Bergkrystall . 62 Berilj . . . 63 Bernstein . 82 Beryll .
# 2023-12-24 20:13:40.937 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.938 | INFO     | __main__:_process_sequence:42 - start token: 75
# 2023-12-24 20:13:40.938 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.938 | INFO     | __main__:_process_sequence:40 - ocr_str: . . * 63 Bimsstein . 52 Bisernik 52 Bizmut. 72 Blende . 81 Bleiglanz . 78 Bobovec . 68 Bohnenerz 68 Boraxsaure 39 Bornit
# 2023-12-24 20:13:40.938 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.939 | INFO     | __main__:_process_sequence:42 - start token: 100
# 2023-12-24 20:13:40.939 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.940 | INFO     | __main__:_process_sequence:40 - ocr_str: . 76 Brauneisenerz 68 Braunkohle 84 Braunstein 68 Brusnfk 86 Buntkup fererz 76 Cerusit 50 Chlorit. 55 Cimetovec . 60 Cinober 80 Citrin . 62
# 2023-12-24 20:13:40.940 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.941 | INFO     | __main__:_process_sequence:42 - start token: 125
# 2023-12-24 20:13:40.941 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.941 | INFO     | __main__:_process_sequence:40 - ocr_str: . 62 . 63 . 58 . 59 . 56 . 72 . 78 . 78 . 84 . 84 . 44 . 45 .
# 2023-12-24 20:13:40.942 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.942 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-24 20:13:40.943 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.943 | INFO     | __main__:_process_sequence:40 - ocr_str: 46 , 63 . 45 . 45 . 79 . 72 . 74 . 59 . 83 . 58 . 88 . 81 . 62
# 2023-12-24 20:13:40.944 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.944 | INFO     | __main__:_process_sequence:42 - start token: 200
# 2023-12-24 20:13:40.944 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-24 20:13:40.944 | INFO     | __main__:_process_sequence:40 - ocr_str: 63 . 45 . 45 . 79 . 72 . 74 . 59 . 83 . 58 . 88 . 81 . 62 . 51
# 2023-12-24 20:13:40.944 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.945 | INFO     | __main__:_process_sequence:42 - start token: 202
# 2023-12-24 20:13:40.951 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-24 20:13:40.952 | INFO     | __main__:_process_sequence:40 - ocr_str: „Novic“ Gospod Skubic M., dekan v Semiču, kot usta- novnik ,, Pleško France, kaplan v Semiču, za let. donesek Po gosp. Vojtehu Candolini-u iz Kostanjevic
# 2023-12-24 20:13:40.952 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.952 | INFO     | __main__:_process_sequence:42 - start token: 900
# 2023-12-24 20:13:40.953 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-24 20:13:40.953 | INFO     | __main__:_process_sequence:40 - ocr_str: so poslali kot ustanovniki: c Gospod Ivan Irkič, c. kr. notar na KrŠksi, ,, Hribar Vatroslav, župan v Jesenicah ,, Markič Matevž, kapi. v Kostanjevici
# 2023-12-24 20:13:40.953 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.953 | INFO     | __main__:_process_sequence:42 - start token: 925
# 2023-12-24 20:13:40.954 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-24 20:13:40.954 | INFO     | __main__:_process_sequence:40 - ocr_str: Ko stanjevici „ Bele France, c. k. preglednik v Ko stanjevici ,, Salcer Ivan, c. kr. gojzdnar v Ko stanjevici „ Setinec Franjo, trgovec v
# 2023-12-24 20:13:40.954 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.954 | INFO     | __main__:_process_sequence:42 - start token: 975
# 2023-12-24 20:13:40.954 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-24 20:13:40.955 | INFO     | __main__:_process_sequence:40 - ocr_str: Vojteh, c. kr. pristav v Kostanjevici ,, Gerdesič Jože, c. kr. aktvar v Ko stanjevici 8105 gold. 84 kr 10 77 7» 2 17 7?
# 2023-12-24 20:13:40.955 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.955 | INFO     | __main__:_process_sequence:42 - start token: 1025
# 2023-12-24 20:13:40.956 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-24 20:13:40.956 | INFO     | __main__:_process_sequence:40 - ocr_str: 10 77 77 10 77 77 10 77 ' 77 2 77 77 2 77 77 2 77 7? 2 M 77 77 2 7?
# 2023-12-24 20:13:40.956 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:40.956 | INFO     | __main__:_process_sequence:42 - start token: 1050
# 2023-12-24 20:13:40.977 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/47.txt"
# 2023-12-24 20:13:40.987 | INFO     | __main__:_process_sequence:40 - ocr_str: nus, liberta) s pristavkom tistega, kdor je je imel v suž nosti n. p. oproščenec Avgustov. Kdor pa ni bil v suž nosti rojen ampak
# 2023-12-24 20:13:41.000 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:41.002 | INFO     | __main__:_process_sequence:42 - start token: 325
# 2023-12-24 20:13:41.003 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/47.txt"
# 2023-12-24 20:13:41.004 | INFO     | __main__:_process_sequence:40 - ocr_str: v suž nosti rojen ampak od prostih staršev, imenoval se je po oprostitvi ingenuus, ingenua (prostorojen) in je zopet vžival vse pravice svojega stanu. *
# 2023-12-24 20:13:41.005 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:41.012 | INFO     | __main__:_process_sequence:42 - start token: 345
# 2023-12-24 20:13:41.026 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/7.txt"
# 2023-12-24 20:13:41.027 | INFO     | __main__:_process_sequence:40 - ocr_str: za druge polke srečkati. Iz Stajarsko-Krajnske meje. Na stranski že leznici, po kteri iz Hrastnika na cesarsko železnico premog vozijo, se je 1. dan t.
# 2023-12-24 20:13:41.027 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:41.027 | INFO     | __main__:_process_sequence:42 - start token: 1000
# 2023-12-24 20:13:41.028 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/7.txt"
# 2023-12-24 20:13:41.028 | INFO     | __main__:_process_sequence:40 - ocr_str: m. grozna nesreča na- ključila. Šel je namreč 60 let star berač Jakob Kraj car, akoravno je ostro prepovedano po stranski želez nici k Savi;
# 2023-12-24 20:13:41.028 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:41.029 | INFO     | __main__:_process_sequence:42 - start token: 1025
# 2023-12-24 20:13:41.030 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/7.txt"
# 2023-12-24 20:13:41.031 | INFO     | __main__:_process_sequence:40 - ocr_str: prihodnje take nesreče zavarovale. Iz Krajnja je došla , ? Novicam a sledeča zahvala: 3. t. m. je umerla moja ljuba sestrica Frančiška Save- ria.
# 2023-12-24 20:13:41.031 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-24 20:13:41.031 | INFO     | __main__:_process_sequence:42 - start token: 1150
# 2023-12-24 20:13:41.064 | INFO     | __main__:<module>:10 - # samples train: 117753, val: 13017, test: 34698)

# %%
train_data
# Out:
#                     key  start_token_id     score  \
# 0        DE/DE4/204.txt               0  0.111111
# 1        DE/DE4/204.txt              25  0.089109
# 2        DE/DE4/204.txt              50  0.110000
# 3        DE/DE4/204.txt              75  0.129213
# 4        DE/DE4/204.txt             100  0.182796
# ...                 ...             ...       ...
# 117748  DE/DE3/3649.txt             100  0.181818
# 117749  DE/DE3/3649.txt             125  0.166667
# 117750  DE/DE3/3649.txt             150  0.209945
# 117751  DE/DE3/3649.txt             175  0.200000
# 117752  DE/DE3/3649.txt             177  0.217143
#
#                                                       ocr  \
# 0       annis ad nauigandum non—erant ufi. Has reficie...
# 1       receptus dare— fe Torius ferebat: milites aded...
# 2       Quibus literis acceptis, infolenti periclitare...
# 3       & ruinis effet deformata,‚ciues fuos primum ad...
# 4       fe comotaretur: quéE Parzxtonio‚uel ä dextra a...
# ...                                                   ...
# 117748  denen Bolfern. gedrucft rerden, mwarum nicht i...
# 117749  der Dauer biefer ben und gedendt wird, wenn er...
# 117750  Siteratur befte— Sandrechts, fünftig auffßören...
# 117751  von 1785 bis 1813 (ein längerer Beit— männer b...
# 117752  bis 1813 (ein längerer Beit— männer bdiefer Dt...
#
#                                                        gs language
# 0       annis ad nauigandum non erant uſi. Has reficie...       DE
# 1       receptus dare-ſe Torius ferebat: milites adeò ...       DE
# 2       Quibus literis acceptis, inſolentipericlitaren...       DE
# 3       & ruinis eſſet deformata, ciues ſuos primùm ad...       DE
# 4       ſe comoraretur: quẽParætonio, uel à dextra ab ...       DE
# ...                                                   ...      ...
# 117748  Voͤlkern.gedruckt werden, warum nicht in Bayer...       DE
# 117749  der Dauer dieſerben und gedruckt wird, wenn er...       DE
# 117750  Literatur beſte Landrechts, kuͤnftig aufhoͤren...       DE
# 117751  von 1785 bis 1815 (ein laͤngerer Zeit maͤnner ...       DE
# 117752  bis 1815 (ein laͤngerer Zeit maͤnner dieſer Mo...       DE
#
# [117753 rows x 6 columns]

# %%
train_data.sample(5)
# Out:
#                     key  start_token_id     score  \
# 97497   DE/DE3/5551.txt             100  0.251656
# 77721    FR/FR1/701.txt              25  0.046243
# 107611    DE/DE5/75.txt             200  0.236220
# 29428   DE/DE3/5342.txt              75  0.186335
# 114404    DE/DE2/46.txt             550  0.116129
#
#                                                       ocr  \
# 97497   bdie fi Sbnen der WGreibeit zu Brauen, da8ß ar...
# 77721   quadium et quaciens in regno nostro existent, ...
# 107611  Simon. unfer ere wirt vil groffer Jen Jes Fepf...
# 29428   batte ja fogar im &erfer davon bufdichte Afuge...
# 114404  man in Der ©reitfopßschen SJtieDerlage 6 Doppe...
#
#                                                        gs language
# 97497   die ſich Jhnender Freiheit zu brauen, das arom...       DE
# 77721   quamdiu et quociens in regno nostro existent, ...       FR
# 107611  Simon.vnſer ere wirt vil groſſer den des keyſe...       DE
# 29428   hatte ja ſogar im Kerker davonbuſchichte Augen...       DE
# 114404  man in der Breitkopﬁschen Niederlage 6 Doppel⸗...       DE

# %%
def add_len(text):
    return len(text)

for df in (train_data, test_data, val_data):
    df["len_ocr"]  = df["ocr"].apply(add_len)
    df["len_gs"]  = df["gs"].apply(add_len)

# %%
for df in (train_data, test_data, val_data):
    print(f"ocr: {df.len_ocr.describe()}")
    print(f"gs: {df.len_gs.describe()}")
# Out:
# ocr: count    117753.000000
# mean        157.385425
# std          23.178839
# min          10.000000
# 25%         142.000000
# 50%         154.000000
# 75%         170.000000
# max         350.000000
# Name: len_ocr, dtype: float64
# gs: count    117753.000000
# mean        154.779946
# std          37.659245
# min           1.000000
# 25%         139.000000
# 50%         151.000000
# 75%         167.000000
# max        5593.000000
# Name: len_gs, dtype: float64
# ocr: count    34698.000000
# mean       156.618854
# std         23.233312
# min         23.000000
# 25%        141.000000
# 50%        154.000000
# 75%        168.000000
# max        338.000000
# Name: len_ocr, dtype: float64
# gs: count    34698.000000
# mean       154.423137
# std         47.574638
# min          1.000000
# 25%        139.000000
# 50%        151.000000
# 75%        166.000000
# max       2718.000000
# Name: len_gs, dtype: float64
# ocr: count    13017.000000
# mean       157.875163
# std         23.141082
# min         60.000000
# 25%        143.000000
# 50%        155.000000
# 75%        170.000000
# max        289.000000
# Name: len_ocr, dtype: float64
# gs: count    13017.000000
# mean       155.515941
# std         35.931659
# min          1.000000
# 25%        139.000000
# 50%        152.000000
# 75%        167.000000
# max       1170.000000
# Name: len_gs, dtype: float64

# %%
# logger.info(f"Filtering train and val based on maximum edit distance of {max_ed}")
# train_data = train_data[train_data.score < max_ed]
# val_data = val_data[val_data.score < max_ed]

# %%
for df in (train_data, val_data, test_data):
    df.drop(columns=["score"], inplace=True)

dataset = DatasetDict(
    {
        "train": Dataset.from_pandas(train_data),
        "val": Dataset.from_pandas(val_data),
        "test": Dataset.from_pandas(test_data),
    }
)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['key', 'start_token_id', 'ocr', 'gs', 'language', 'len_ocr', 'len_gs'],
#         num_rows: 117753
#     })
#     val: Dataset({
#         features: ['key', 'start_token_id', 'ocr', 'gs', 'language', 'len_ocr', 'len_gs'],
#         num_rows: 13017
#     })
#     test: Dataset({
#         features: ['key', 'start_token_id', 'ocr', 'gs', 'language', 'len_ocr', 'len_gs'],
#         num_rows: 34698
#     })
# })

# %%
from transformers import AutoTokenizer

checkpoint = "google/byt5-small"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
max_len = 200

def preprocess_function(examples):
    ocr_texts = [doc for doc in examples["ocr"]]
    model_inputs = tokenizer(ocr_texts, max_length=max_len, truncation=True)

    gs_texts = [doc for doc in examples["gs"]]
    labels = tokenizer(text_target=gs_texts, max_length=max_len, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/117753 [00:00<?, ? examples/s]
# Map:   0%|          | 0/13017 [00:00<?, ? examples/s]
# Map:   0%|          | 0/34698 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

# %%
from evaluate import load
cer = load("cer")

# %%
cer_score = cer.compute(predictions=val_data.ocr.to_list(), references=val_data.gs.to_list())
print(cer_score)
# Out:
# 0.21237264855586288

# %%
wer = load("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %%
wer_score = wer.compute(predictions=val_data.ocr.to_list(), references=val_data.gs.to_list())
print(wer_score)
# Out:
# 0.635085134039459

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Downloading generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="my_awesome_billsum_model",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=4,
    predict_with_generate=True,
    # fp16=True,
    push_to_hub=False,
    load_best_model_at_end="epoch",
    save_strategy="epoch",
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    # compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: ocr, language, len_gs, len_ocr, start_token_id, gs, key. If ocr, language, len_gs, len_ocr, start_token_id, gs, key are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /Users/janneke/code/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 117753
#   Num Epochs = 4
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 29440
#   Number of trainable parameters = 299637760
#   0%|          | 0/29440 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 trainer.train()
#
# File ~/code/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages/transformers/trainer.py:1543, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1538     self.model_wrapped = self.model
#    1540 inner_training_loop = find_executable_batch_size(
#    1541     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1542 )
# -> 1543 return inner_training_loop(
#    1544     args=args,
#    1545     resume_from_checkpoint=resume_from_checkpoint,
#    1546     trial=trial,
#    1547     ignore_keys_for_eval=ignore_keys_for_eval,
#    1548 )
#
# File ~/code/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages/transformers/trainer.py:1791, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1789         tr_loss_step = self.training_step(model, inputs)
#    1790 else:
# -> 1791     tr_loss_step = self.training_step(model, inputs)
#    1793 if (
#    1794     args.logging_nan_inf_filter
#    1795     and not is_torch_tpu_available()
#    1796     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1797 ):
#    1798     # if loss is nan or inf simply add the average of previous logged losses
#    1799     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/code/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages/transformers/trainer.py:2557, in Trainer.training_step(self, model, inputs)
#    2555     loss = self.deepspeed.backward(loss)
#    2556 else:
# -> 2557     loss.backward()
#    2559 return loss.detach()
#
# File ~/code/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/code/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
