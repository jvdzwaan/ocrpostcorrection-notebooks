# %% [markdown]
# # Train T5 for ocr postcorrection
#
# Sources
# * https://huggingface.co/docs/transformers/tasks/summarization

# %% [markdown]
# ## Data
#
# * In: sequence with ocr errors
# * Out: sequence without ocr errors
# * Task prefix: `correct: `
#     * Not sure this is necessary...

# %%
from google.colab import drive
drive.mount('/mntDrive')

# %%
! git clone https://github.com/jvdzwaan/ocrpostcorrection-notebooks.git

# %%
# %cd /content/ocrpostcorrection-notebooks

# %%
! pip install poetry

# %%
# Configure poetry to create virtual environments in the project folder
! poetry config virtualenvs.in-project true

# %%
! poetry install --no-ansi

# %%
# Add poetry virtual environment to python path so that all installed dependencies can be found by the python interpreter

import sys
sys.path.append("/content/ocrpostcorrection-notebooks/.venv/lib/python3.8/site-packages")

# %%
! cp /mntDrive/MyDrive/ocrpostcorrection-config/config.local .dvc/config.local

# %%
! poetry run dvc pull -r gdrive

# %%
from pathlib import Path

import pandas as pd
from datasets import Dataset, DatasetDict
from loguru import logger
from ocrpostcorrection.icdar_data import get_intermediate_data

# %%
raw_dataset = Path('..')/'data'/'raw'/'ICDAR2019_POCR_competition_dataset.zip'

train_split = Path('..')/'data'/'splits'/'train.csv'
val_split = Path('..')/'data'/'splits'/'val.csv'
test_split = Path('..')/'data'/'splits'/'test.csv'

# %%
data, _, data_test, _ = get_intermediate_data(raw_dataset)
# Out:
# 10it [00:30,  3.09s/it]
# 10it [00:09,  1.08it/s]

# %%
X_train = pd.read_csv(train_split, index_col=0)
X_val = pd.read_csv(val_split, index_col=0)
X_test = pd.read_csv(test_split, index_col=0)

# %%
from typing import List, Dict, Tuple
from tqdm.notebook import tqdm

import edlib
from ocrpostcorrection.icdar_data import window, normalized_ed, Text


def _process_sequence(
    key: str,
    i: int,
    res,
    ocr_sents: List[str],
    gs_sents: List[str],
    keys: List[str],
    start_tokens: List[int],
    scores: List[float],
    languages: List[str],
) -> Tuple[
    List[str], List[str], List[str], List[int], List[float], List[str]
]:
    ocr = [t.ocr for t in res]
    gs = []
    for t in res:
        if t.gs != "":
            gs.append(t.gs)
    ocr_str = " ".join(ocr)
    gs_str = " ".join(gs)
    ed = edlib.align(ocr_str, gs_str)["editDistance"]
    score = normalized_ed(ed, ocr_str, gs_str)

    if len(ocr_str) > 0 and len(gs_str) > 0:
        ocr_sents.append(ocr_str)
        gs_sents.append(gs_str)
        keys.append(key)
        start_tokens.append(i)
        scores.append(score)
        languages.append(key[:2])
    else:
        logger.info(f'Empty sample for text "{key}"')
        logger.info(f"ocr_str: {ocr_str}")
        logger.info(f"gs_str: {gs_str}")
        logger.info(f"start token: {i}")

    return (ocr_sents, gs_sents, keys, start_tokens, scores, languages)


def generate_sentences(
    df: pd.DataFrame, data: Dict[str, Text], size: int = 15, step: int = 10
) -> pd.DataFrame:
    """Generate sequences of a certain length and possible overlap"""
    ocr_sents: List[str] = []
    gs_sents: List[str] = []
    keys: List[str] = []
    start_tokens: List[int] = []
    scores: List[float] = []
    languages: List[str] = []

    for _, row in tqdm(df.iterrows()):
        key = row.file_name
        tokens = data[key].input_tokens

        # print(len(tokens))
        # print(key)
        for i, res in enumerate(window(tokens, size=size)):
            if i % step == 0:
                (
                    ocr_sents,
                    gs_sents,
                    keys,
                    start_tokens,
                    scores,
                    languages,
                ) = _process_sequence(
                    key, i, res, ocr_sents, gs_sents, keys, start_tokens, scores, languages
                )
        # Add final sequence
        (ocr_sents, gs_sents, keys, start_tokens, scores, languages) = _process_sequence(
            key, i, res, ocr_sents, gs_sents, keys, start_tokens, scores, languages
        )

    output = pd.DataFrame(
        {
            "key": keys,
            "start_token_id": start_tokens,
            "score": scores,
            "ocr": ocr_sents,
            "gs": gs_sents,
            "language": languages,
        }
    )

    # Adding the final sequence may lead to duplicate rows. Remove those
    output.drop_duplicates(
        subset=["key", "start_token_id"], keep="first", inplace=True, ignore_index=True
    )

    return output

# %%
size = 35
step = 35

# %%
logger.info(f"Generating sentences (size: {size}, step: {step})")

train_data = generate_sentences(X_train, data, size=size, step=step)
val_data = generate_sentences(X_val, data, size=size, step=step)
test_data = generate_sentences(X_test, data_test, size=size, step=size)

num_train = train_data.shape[0]
num_val = val_data.shape[0]
num_test = test_data.shape[0]
logger.info(f"# samples train: {num_train}, val: {num_val}, test: {num_test})")
# Out:
# 2023-12-15 12:05:56.275 | INFO     | __main__:<module>:1 - Generating sentences (size: 35, step: 35)
# 0it [00:00, ?it/s]
# 2023-12-15 12:05:56.378 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-15 12:05:56.379 | INFO     | __main__:_process_sequence:40 - ocr_str: Philippus naces lit regie dengnitatis, chemencam e ilionlibenter extenimus et seiu eorum liberali promonemus affectu, qui not serviciorm exnbicine grata pervenint et virtutum comis suffragis, digne sibi venditant primia mentorum. Nomnacaque facimus aniversi, tam presentibus
# 2023-12-15 12:05:56.379 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:56.380 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:56.380 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-15 12:05:56.381 | INFO     | __main__:_process_sequence:40 - ocr_str: quad futuris, pro lict Jihes Guibti, clericus et Guillelmus ejus fratis, corhibitis cipulis de Conjignes, vides et solutis extum habuisse dicantur. Nos, attendentos quod, sicut relacio fide digna testitur ipsi ad prtorum imittanda vestigia ferventer
# 2023-12-15 12:05:56.382 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:56.382 | INFO     | __main__:_process_sequence:42 - start token: 35
# 2023-12-15 12:05:56.383 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-15 12:05:56.383 | INFO     | __main__:_process_sequence:40 - ocr_str: intenti sint sio affinrunt ubtate virtutumquod hujusmodi crenitur Maculami, sic eoram probitatu decore abstergit, ut eos à tol attalli favoribus graciosis debitum reputenis ac propter ea et intuitu dicti servici nobis impensi suis supplicacionibus annentes
# 2023-12-15 12:05:56.384 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:56.385 | INFO     | __main__:_process_sequence:42 - start token: 70
# 2023-12-15 12:05:56.386 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-15 12:05:56.386 | INFO     | __main__:_process_sequence:40 - ocr_str: de certa sciencia et speciali gracia ac plenitudine regie potestatis predicte Johannem et Guillem de Copulis, predictis genitor ad honores solares actusque legitimos queslibet, quo ad tempalia tenendam, tenore presencium legittumitatis ticulo decorania hujusmodi geniture
# 2023-12-15 12:05:56.387 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:56.387 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:05:56.388 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/904.txt"
# 2023-12-15 12:05:56.388 | INFO     | __main__:_process_sequence:40 - ocr_str: Mailam, quo ad premissa penitus abelenes et concedentes eisdem, ec cordem alteri ut cum eis et eorum quolibet, tenore presenciu dispensantes de sciencia, po testate et auctoritate predcis, ut ipsi canque leguatum sucdere valeant et
# 2023-12-15 12:05:56.389 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:56
| INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.034 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:05:57.047 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/130.txt"
# 2023-12-15 12:05:57.047 | INFO     | __main__:_process_sequence:40 - ocr_str: I _____ I Cl E NCT A -a 9 OZK ACH 4' kamienny poflument. t ciwoth tylko był formowany matcryi, 1 kamienia y drzewa pewnego; trąd uroflo przyffowic: Non tx qut> vis Ugno fit Mer>
# 2023-12-15 12:05:57.048 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.048 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.058 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/313.txt"
# 2023-12-15 12:05:57.058 | INFO     | __main__:_process_sequence:40 - ocr_str: en biens sont où estoient pour ce prins, saisiz arrestez ou empeschez mectes les le ou faites mettre tamps e sans delay à plaine delivrance. Et affin que ce soit chose fomme et estable à
# 2023-12-15 12:05:57.059 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.060 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.085 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR1/293.txt"
# 2023-12-15 12:05:57.086 | INFO     | __main__:_process_sequence:40 - ocr_str: Donu factum habitatoribus ville de Angulis, et certe plates situate juxta ecclesiam dicte ville per civitio faciendo, cum dono dugiidi et trium Pictarim pro dicta terra domino regi, anno quolibet debitis et propter hoc debet
# 2023-12-15 12:05:57.087 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.087 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.150 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/14.txt"
# 2023-12-15 12:05:57.151 | INFO     | __main__:_process_sequence:40 - ocr_str: ■
# 2023-12-15 12:05:57.151 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.152 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.153 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/14.txt"
# 2023-12-15 12:05:57.153 | INFO     | __main__:_process_sequence:40 - ocr_str: ■
# 2023-12-15 12:05:57.154 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.154 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.169 | INFO     | __main__:_process_sequence:39 - Empty sample for text "DE/DE2/131.txt"
# 2023-12-15 12:05:57.169 | INFO     | __main__:_process_sequence:40 - ocr_str: ^Reparaturen an ben : ÜRafcpinen oorgenommen »erben sönnen, opne ben ganzen Betrieb ju stören/ in ! Sachsen"Sßcimar »irb angeführt, bap bie nicht arbeitenben Betriebe »on geringem Umfange feien unb nicht für ben (Export arbeiteten. ,
# 2023-12-15 12:05:57.170 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.171 | INFO     | __main__:_process_sequence:42 - start token: 280
# 2023-12-15 12:05:57.243 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-15 12:05:57.243 | INFO     | __main__:_process_sequence:40 - ocr_str: mm. * mm «ma w* #m *** un ,m#a -mm waa; mm mm mm '*# mu mm »## mm mm mw# em* w#i ## &## maa aaaa ■■# w* mw, ### wm am mm mm
# 2023-12-15 12:05:57.244 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.245 | INFO     | __main__:_process_sequence:42 - start token: 70
# 2023-12-15 12:05:57.245 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-15 12:05:57.246 | INFO     | __main__:_process_sequence:40 - ocr_str: mm mm ms* mm awn w% wr mmc umm tmm mm mmm tmm mm» mtm mm ama ymn mrnv ***** tam mm mm mm mm .mm mm mm mm mmm .m* mm tmm <mu mm
# 2023-12-15 12:05:57.246 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.247 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:05:57.248 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-15 12:05:57.249 | INFO     | __main__:_process_sequence:40 - ocr_str: i#, #*# %ma aw %w a# w r#a ##* a# aww u# ——• tmm mm yu #ra# «a m# wx ##i #*w #*# >wto awa y## mr% au* amar #a ** * ** mw w*
# 2023-12-15 12:05:57.249 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.250 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-15 12:05:57.250 | INFO     | __main__:_process_sequence:39 - Empty sample for text "FR/FR3/79.txt"
# 2023-12-15 12:05:57.251 | INFO     | __main__:_process_sequence:40 - ocr_str: mm mm mm marna ## maaa mm a# au *w aw maa mw *# #■' aw «a* mw ma# w &a# m ma# a#, ma *a mm mm aw a# %m mrm mm mm# #f,
# 2023-12-15 12:05:57.252 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.252 | INFO     | __main__:_process_sequence:42 - start token: 210
# 2023-12-15 12:05:57.271 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/123.txt"
# 2023-12-15 12:05:57.272 | INFO     | __main__:_process_sequence:40 - ocr_str: lepe Jezusove nauke. Kako lepo podobo prave sve tosti nam Jezus z malo besedami tukaj popiše! Kako obilen Studenic čiste sreče nam odpre v našim lastnim sercu! Tak naj bo kdo, tako odvezen od pozemeljskiga,
# 2023-12-15 12:05:57.272 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.273 | INFO     | __main__:_process_sequence:42 - start token: 210
# 2023-12-15 12:05:57.274 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/123.txt"
# 2023-12-15 12:05:57.274 | INFO     | __main__:_process_sequence:40 - ocr_str: Tak naj bo kdo, tako odvezen od pozemeljskiga, tako iz serca po nižen, tako tih ino poterpežljiv vterpljenji, tako pohleven ino krotak, tako vnet za vse dobro, tako mil ino usmiljen, tako nedolžen brez ovin-
# 2023-12-15 12:05:57.275 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.276 | INFO     | __main__:_process_sequence:42 - start token: 237
# 2023-12-15 12:05:57.311 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/120.txt"
# 2023-12-15 12:05:57.312 | INFO     | __main__:_process_sequence:40 - ocr_str: t r'""\ i r
# 2023-12-15 12:05:57.312 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.313 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.313 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/120.txt"
# 2023-12-15 12:05:57.314 | INFO     | __main__:_process_sequence:40 - ocr_str: t r'""\ i r
# 2023-12-15 12:05:57.315 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.315 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.379 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/80.txt"
# 2023-12-15 12:05:57.379 | INFO     | __main__:_process_sequence:40 - ocr_str: r
# 2023-12-15 12:05:57.380 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.381 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.381 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/80.txt"
# 2023-12-15 12:05:57.382 | INFO     | __main__:_process_sequence:40 - ocr_str: r
# 2023-12-15 12:05:57.382 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.383 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.486 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/72.txt"
# 2023-12-15 12:05:57.487 | INFO     | __main__:_process_sequence:40 - ocr_str: opened at Half-past Six o'Clock, and the Curtain will rise precisely at Seven. (£3- The BOX-OFFICE will be Opened Daily, from Ten until Four, under the Superintendance of Mr. BUCKE, of wham Places and Private
# 2023-12-15 12:05:57.487 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.488 | INFO     | __main__:_process_sequence:42 - start token: 490
# 2023-12-15 12:05:57.488 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/72.txt"
# 2023-12-15 12:05:57.489 | INFO     | __main__:_process_sequence:40 - ocr_str: Boxes may be taken. For the greater accommodation of the Public, Places may be taken from Four till Six o’Clock, at No. 4, Little Russell Street, facing the Stage Entrance. VIVAN T REX ET REGINA.
# 2023-12-15 12:05:57.490 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.490 | INFO     | __main__:_process_sequence:42 - start token: 525
# 2023-12-15 12:05:57.491 | INFO     | __main__:_process_sequence:39 - Empty sample for text "EN/EN1/72.txt"
# 2023-12-15 12:05:57.492 | INFO     | __main__:_process_sequence:40 - ocr_str: taken from Four till Six o’Clock, at No. 4, Little Russell Street, facing the Stage Entrance. VIVAN T REX ET REGINA. No Money lo be returned J. Tibby,” Prioter, Tbe.tr* Roy. 1 , Dr.ij Las*.
# 2023-12-15 12:05:57.492 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.493 | INFO     | __main__:_process_sequence:42 - start token: 539
# 2023-12-15 12:05:57.510 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1
| INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.763 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.763 | INFO     | __main__:_process_sequence:39 - Empty sample for text "ES/ES1/132.txt"
# 2023-12-15 12:05:57.764 | INFO     | __main__:_process_sequence:40 - ocr_str: se puede esperar beneficio ii dádiva, por su genio es calio , se ha de tomar lo que primero die re, aunque sea de poco precio y valor. Lat. Anxiüs acdphs quidquid tibí donat avaras
# 2023-12-15 12:05:57.765 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.765 | INFO     | __main__:_process_sequence:42 - start token: 35
# 2023-12-15 12:05:57.813 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/90.txt"
# 2023-12-15 12:05:57.814 | INFO     | __main__:_process_sequence:40 - ocr_str: 30 PhilAdelphüs indien de Hr. A. dit boek gelezen heeft, öf nog gelieft te lezen, zal hij wel weten, dat het niet mijne zwarigheden zijn, die mij het bewuste Labadistisch leerflelfel doen af keuren, eri
# 2023-12-15 12:05:57.814 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.815 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.815 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/90.txt"
# 2023-12-15 12:05:57.816 | INFO     | __main__:_process_sequence:40 - ocr_str: een an der aannemen; maar dat het zijn de zwarigheden van de opregten, die in ’t begin dezer Eeüwe leef den , en den naam hadden, van door vroomheid en naauwgezetheid in de bediening uittemunten.
# 2023-12-15 12:05:57.817 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.817 | INFO     | __main__:_process_sequence:42 - start token: 35
# 2023-12-15 12:05:57.818 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/90.txt"
# 2023-12-15 12:05:57.819 | INFO     | __main__:_process_sequence:40 - ocr_str: de Labadisten , dezelfde beginfels heb bendé, maar ze in de praktijk ook ^villende opVoh gen, hadden om die reden , onze Kerk reeds verla ten) dat de leer van de Neerlandfche gereformeerde Kerk *
# 2023-12-15 12:05:57.819 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.820 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:05:57.820 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/90.txt"
# 2023-12-15 12:05:57.821 | INFO     | __main__:_process_sequence:40 - ocr_str: en derzelver praktijk des algemeenen Kin- derdoops in zulk eene volflrckte ftrijdigheid (ton den, dat zij ónmogelijk met elkander konden wor den ovèreengebragt. Ook heeft zig, zoo veel tot mijne kennis gekomen is, niemand opgedaan,
# 2023-12-15 12:05:57.822 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.822 | INFO     | __main__:_process_sequence:42 - start token: 140
# 2023-12-15 12:05:57.823 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/90.txt"
# 2023-12-15 12:05:57.823 | INFO     | __main__:_process_sequence:40 - ocr_str: die deze ftrijdigheid heeft opgelost, gelijk zulks ook niet gefchieden konde door iemand, die de leer on zer Kerke op denzelfden voet Verklaarde, als de Heeren Meijer en Kelderman. Bij al wat dierbaar was, riepen
# 2023-12-15 12:05:57.824 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.825 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-15 12:05:57.825 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/90.txt"
# 2023-12-15 12:05:57.826 | INFO     | __main__:_process_sequence:40 - ocr_str: deze mannen openlijk om Hervorming, en toonden met kragt van reden aan, dat de open bare praktijk der Kerke met hare aangenomene grondregels behoorde overeengebragt te worden; maar, zonder hunne grondregels te betwisten, of derzelver
# 2023-12-15 12:05:57.826 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.827 | INFO     | __main__:_process_sequence:42 - start token: 210
# 2023-12-15 12:05:57.890 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/65.txt"
# 2023-12-15 12:05:57.891 | INFO     | __main__:_process_sequence:40 - ocr_str: ^er-Aasti*. r ( Ast/. TC.IC. yiAi^z. 64 ■
# 2023-12-15 12:05:57.891 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57.892 | INFO     | __main__:_process_sequence:42 - start token: 0
# 2023-12-15 12:05:57.893 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/65.txt"
# 2023-12-15 12:05:57.893 | INFO     | __main__:_process_sequence:40 - ocr_str: ^er-Aasti*. r ( Ast/. TC.IC. yiAi^z. 64 ■
# 2023-12-15 12:05:57.894 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:57
| INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:05:58.787 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:05:58.788 | INFO     | __main__:_process_sequence:39 - Empty sample for text "DE/DE2/89.txt"
# 2023-12-15 12:05:58.788 | INFO     | __main__:_process_sequence:40 - ocr_str: ®crse(6e. - Sngouf, jun. gest. uaef) ber ©ujle. Äerfel&e. 12 8fe6e. g«|t. ot(j. Merc. de Franc. 1776. T. IV. Slubett, 4 - - ? 1664. gest. beffen ntuftfal. ©eefenetquief. 33erfe(6e. 8 9t. #.©9fofu$. ©. 3sef6urg.
# 2023-12-15 12:05:58.789 | INFO     | __main__:_process_sequence:41 - gs_str:
# ...
# 2023-12-15 12:06:10.924 | INFO     | __main__:_process_sequence:42 - start token: 1260
# 2023-12-15 12:06:10.943 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/39.txt"
# 2023-12-15 12:06:10.944 | INFO     | __main__:_process_sequence:40 - ocr_str: dien mam bekend•, en dat, zonder dien Naam, niet anders, dan telkens door eene zeer breede omfchrijving zou kunnen worden aangeduid. Meer bedoelde ik hier in niet; en nademaal het modig was, dat ik dien
# 2023-12-15 12:06:10.944 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:10.945 | INFO     | __main__:_process_sequence:42 - start token: 35
# 2023-12-15 12:06:10.945 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/39.txt"
# 2023-12-15 12:06:10.946 | INFO     | __main__:_process_sequence:40 - ocr_str: Naam in den tegenwoor- digen Brief wederom meenigemalen gebruikte, ver zoek ik elk, die goedvinden zal den zelven te le zen , dat hij dien in dezen, en in geenen ande ren zin gelieve te
# 2023-12-15 12:06:10.946 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:10.947 | INFO     | __main__:_process_sequence:42 - start token: 70
# 2023-12-15 12:06:10.948 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/39.txt"
# 2023-12-15 12:06:10.948 | INFO     | __main__:_process_sequence:40 - ocr_str: verf aan. Want de Naam La- badist is bij mij alzoo weinig een fcheldnaam, als die van Vitringist, Lampeaan of Honertiaan; wel ken men immers noemen kan, zonder iemand te beledigen? vfangezien zij niets anders
# 2023-12-15 12:06:10.949 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:10.949 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:06:10.950 | INFO     | __main__:_process_sequence:39 - Empty sample for text "NL/NL1/39.txt"
# 2023-12-15 12:06:10.950 | INFO     | __main__:_process_sequence:40 - ocr_str: aanduiden dan zekere denkwijzen, die allen, even als het Labadismus, tot het Cocceanismus behoor en, of daar van onderdeelen uitmaken. hierom heb ik ook niet dan met leetwezen gezien, dat de Heer Alethophilus van zig
# 2023-12-15 12:06:10.951 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:10.951 | INFO     | __main__:_process_sequence:42 - start token: 140
# 2023-12-15 12:06:11.019 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-15 12:06:11.020 | INFO     | __main__:_process_sequence:40 - ocr_str: - Homerus Poeta urodził fię - - - Saul oślic fzukaiący, od Samuela Proroka na Króla na mazany - ARKA Pańflka od Filiftynow wzięta, Dagona Bożka fkrufzyła 50 tyfięcy Betjanttow trupem położyła ( nie uczciwie
# 2023-12-15 12:06:11.021 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.021 | INFO     | __main__:_process_sequence:42 - start token: 35
# 2023-12-15 12:06:11.022 | INFO     | __main__:_process_sequence:39 - Empty sample for text "PL/PL1/43.txt"
# 2023-12-15 12:06:11.023 | INFO     | __main__:_process_sequence:40 - ocr_str: patrzą cych na nie, ) y Ozę Kapłana. “ s * Salomon od BOGA wzioł Mądrość y Bogaftwa. Salomon założył Dom Boży - - - Salomon rzucił fundamenta na Bałwochwalnicę Bożkow Metres fwoich- - -
# 2023-12-15 12:06:11.023 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11
| INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-15 12:06:11.140 | INFO     | __main__:_process_sequence:40 - ocr_str: . 52 Bisernik 52 Bizmut. 72 Blende . 81 Bleiglanz . 78 Bobovec . 68 Bohnenerz 68 Boraxsaure 39 Bornit . 76 Brauneisenerz 68 Braunkohle 84 Braunstein 68 Brusnfk 86 Buntkup fererz 76 Cerusit 50
# 2023-12-15 12:06:11.141 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.142 | INFO     | __main__:_process_sequence:42 - start token: 105
# 2023-12-15 12:06:11.142 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-15 12:06:11.143 | INFO     | __main__:_process_sequence:40 - ocr_str: . 62 . 63 . 58 . 59 . 56 . 72 . 78 . 78 . 84 . 84 . 44 . 45 . 46 , 63 . 45 . 45 . 79 .
# 2023-12-15 12:06:11.143 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.144 | INFO     | __main__:_process_sequence:42 - start token: 175
# 2023-12-15 12:06:11.144 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/30.txt"
# 2023-12-15 12:06:11.145 | INFO     | __main__:_process_sequence:40 - ocr_str: 84 . 84 . 44 . 45 . 46 , 63 . 45 . 45 . 79 . 72 . 74 . 59 . 83 . 58 . 88 . 81 . 62 . 51
# 2023-12-15 12:06:11.145 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.146 | INFO     | __main__:_process_sequence:42 - start token: 192
# 2023-12-15 12:06:11.157 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-15 12:06:11.158 | INFO     | __main__:_process_sequence:40 - ocr_str: ,, Pleško France, kaplan v Semiču, za let. donesek Po gosp. Vojtehu Candolini-u iz Kostanjevic so poslali kot ustanovniki: c Gospod Ivan Irkič, c. kr. notar na KrŠksi, ,, Hribar Vatroslav, župan v Jesenicah ,,
# 2023-12-15 12:06:11.158 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.159 | INFO     | __main__:_process_sequence:42 - start token: 910
# 2023-12-15 12:06:11.160 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-15 12:06:11.160 | INFO     | __main__:_process_sequence:40 - ocr_str: Ko stanjevici ,, Melher Ant., nadgojzdnar v Jesenicah „ Candolini Vojteh, c. kr. pristav v Kostanjevici ,, Gerdesič Jože, c. kr. aktvar v Ko stanjevici 8105 gold. 84 kr 10 77 7» 2 17 7?
# 2023-12-15 12:06:11.161 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.161 | INFO     | __main__:_process_sequence:42 - start token: 1015
# 2023-12-15 12:06:11.162 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/34.txt"
# 2023-12-15 12:06:11.163 | INFO     | __main__:_process_sequence:40 - ocr_str: 10 77 77 10 77 77 10 77 ' 77 2 77 77 2 77 77 2 77 7? 2 M 77 77 2 7? 77 2 77 77 2 77 77 2 77 77
# 2023-12-15 12:06:11.163 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.164 | INFO     | __main__:_process_sequence:42 - start token: 1050
# 2023-12-15 12:06:11.176 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/47.txt"
# 2023-12-15 12:06:11.177 | INFO     | __main__:_process_sequence:40 - ocr_str: suž nosti n. p. oproščenec Avgustov. Kdor pa ni bil v suž nosti rojen ampak od prostih staršev, imenoval se je po oprostitvi ingenuus, ingenua (prostorojen) in je zopet vžival vse pravice svojega stanu. *
# 2023-12-15 12:06:11.178 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.178 | INFO     | __main__:_process_sequence:42 - start token: 335
# 2023-12-15 12:06:11.185 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/7.txt"
# 2023-12-15 12:06:11.185 | INFO     | __main__:_process_sequence:40 - ocr_str: na cesarsko železnico premog vozijo, se je 1. dan t. m. grozna nesreča na- ključila. Šel je namreč 60 let star berač Jakob Kraj car, akoravno je ostro prepovedano po stranski želez nici k Savi;
# 2023-12-15 12:06:11.186 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.186 | INFO     | __main__:_process_sequence:42 - start token: 1015
# 2023-12-15 12:06:11.188 | INFO     | __main__:_process_sequence:39 - Empty sample for text "SL/SL1/7.txt"
# 2023-12-15 12:06:11.196 | INFO     | __main__:_process_sequence:40 - ocr_str: veliko nesrečo pripra vil, ga je morebiti prepozno zagledal, da voza več ustaviti ni mogel, in berača povozil. Ubogi starčik je bil tako raztergan , da skorej človeške podobe več imel ni. Nemarni voznik je
# 2023-12-15 12:06:11.199 | INFO     | __main__:_process_sequence:41 - gs_str:
# 2023-12-15 12:06:11.204 | INFO     | __main__:_process_sequence:42 - start token: 1085
# 2023-12-15 12:06:11.247 | INFO     | __main__:<module>:10 - # samples train: 85767, val: 9474, test: 25258)

# %%
train_data
# Out:
#                    key  start_token_id     score  \
# 0       DE/DE4/204.txt               0  0.100000
# 1       DE/DE4/204.txt              35  0.100346
# 2       DE/DE4/204.txt              70  0.151751
# 3       DE/DE4/204.txt             105  0.137500
# 4       DE/DE4/204.txt             140  0.113122
# ...                ...             ...       ...
# 85762  DE/DE3/3649.txt              35  0.208661
# 85763  DE/DE3/3649.txt              70  0.203320
# 85764  DE/DE3/3649.txt             105  0.140625
# 85765  DE/DE3/3649.txt             140  0.200820
# 85766  DE/DE3/3649.txt             167  0.216102
#
#                                                      ocr  \
# 0      annis ad nauigandum non—erant ufi. Has reficie...
# 1      nomen in fcutis Non dubitanter Alexandrini cla...
# 2      uideretut,fimul ut contra fimis incédiis & rui...
# 3      dextra ab infula:qug diuerfx nauig3tiones nunq...
# 4      calamum obtuflorem, B 3 los qui domi quzratnum...
# ...                                                  ...
# 85762  ffarb jene 'Bemüßbungen nicht vorbergegangen w...
# 85763  bier der größte Berlag von eloffifhen Hu— Öemi...
# 85764  nicht in Bayern Cotta's befeitigt woerden fönn...
# 85765  &Cprache und Siterati . den, daß, wenn uberbau...
# 85766  müffen nwiffen, warum fie lieber Rapita— 30 NX...
#
#                                                       gs language
# 0      annis ad nauigandum non erant uſi. Has reficie...       DE
# 1      nomen in ſcutisNon dubitanter Alexandrini claſ...       DE
# 2      uideretur, ſimul ut contraſimis incẽdiis & rui...       DE
# 3      dextra ab inſula: quę diuerſæ nauigationes nun...       DE
# 4      calamum obtuſiorem,B 3 losqui domi quærat num ...       DE
# ...                                                  ...      ...
# 85762  ſtarbjene Bemuͤhungen nicht vorhergegangen waͤ...       DE
# 85763  hier der groͤßte Verlag von claſſiſchen Au Gew...       DE
# 85764  nicht in Bayern Cotta'sbeſeitigt werden koͤnne...       DE
# 85765  Sprache und Literatur.den, daß, wenn uͤberhaup...       DE
# 85766  muͤſſen wiſſen, warum ſie lieber Kapita 30 Jah...       DE
#
# [85767 rows x 6 columns]

# %%
train_data.sample(5)
# Out:
#                   key  start_token_id     score  \
# 47227  FR/FR3/815.txt               0  0.045977
# 14173  DE/DE5/115.txt             105  0.314516
# 34358  DE/DE6/206.txt             140  0.355140
# 12720   BG/BG1/43.txt             315  0.098837
# 21629  FR/FR1/334.txt             525  0.014563
#
#                                                      ocr  \
# 47227  MERCI et à très BIENTOT Unité U - Balance: O -...
# 14173  attendens 4d agat iuidef. Art.i:G met?fübiecif...
# 34358  Böle fes wird refolisteren» ° Diafcorides fpri...
# 12720  поиитахъ ж азъ. — За да сн намЬрж имание, отго...
# 21629  et successeurs perpetuelment toute juridicion ...
#
#                                                       gs language
# 47227  MERCI et à très BIENTOT Unité: 0 – Balance: O ...       FR
# 14173  attendens qͥd agatĩuidet᷑. At.i:ſʒ metꝰ ſubiec...       DE
# 34358  boͤſe feuch⸗vnd reſoluieren · ¶ Diaſcorides ſp...       DE
# 12720  попитахъ ѭ азъ.   За да си намѣрѭ имание, отго...       BG
# 21629  et successeurs perpetuelment toute juridicion ...       FR

# %%
def add_len(text):
    return len(text)

for df in (train_data, test_data, val_data):
    df["len_ocr"]  = df["ocr"].apply(add_len)
    df["len_gs"]  = df["gs"].apply(add_len)

# %%
for df in (train_data, test_data, val_data):
    print(f"ocr: {df.len_ocr.describe()}")
    print(f"gs: {df.len_gs.describe()}")
# Out:
# ocr: count    85767.000000
# mean       220.624389
# std         30.413322
# min         10.000000
# 25%        201.000000
# 50%        217.000000
# 75%        236.000000
# max        464.000000
# Name: len_ocr, dtype: float64
# gs: count    85767.000000
# mean       216.818100
# std         48.505311
# min          1.000000
# 25%        197.000000
# 50%        212.000000
# 75%        232.000000
# max       5593.000000
# Name: len_gs, dtype: float64
# ocr: count    25258.000000
# mean       219.577955
# std         30.525005
# min         23.000000
# 25%        200.000000
# 50%        216.000000
# 75%        234.000000
# max        510.000000
# Name: len_ocr, dtype: float64
# gs: count    25258.000000
# mean       216.189207
# std         60.897175
# min          1.000000
# 25%        196.000000
# 50%        211.000000
# 75%        231.000000
# max       3998.000000
# Name: len_gs, dtype: float64
# ocr: count    9474.000000
# mean      221.269263
# std        30.127878
# min        99.000000
# 25%       202.000000
# 50%       217.000000
# 75%       237.000000
# max       401.000000
# Name: len_ocr, dtype: float64
# gs: count    9474.000000
# mean      217.825100
# std        46.391353
# min         2.000000
# 25%       197.000000
# 50%       213.000000
# 75%       233.000000
# max      1223.000000
# Name: len_gs, dtype: float64

# %%
# logger.info(f"Filtering train and val based on maximum edit distance of {max_ed}")
# train_data = train_data[train_data.score < max_ed]
# val_data = val_data[val_data.score < max_ed]

# %%
for df in (train_data, val_data, test_data):
    df.drop(columns=["score"], inplace=True)

dataset = DatasetDict(
    {
        "train": Dataset.from_pandas(train_data),
        "val": Dataset.from_pandas(val_data),
        "test": Dataset.from_pandas(test_data),
    }
)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['key', 'start_token_id', 'ocr', 'gs', 'language', 'len_ocr', 'len_gs'],
#         num_rows: 85767
#     })
#     val: Dataset({
#         features: ['key', 'start_token_id', 'ocr', 'gs', 'language', 'len_ocr', 'len_gs'],
#         num_rows: 9474
#     })
#     test: Dataset({
#         features: ['key', 'start_token_id', 'ocr', 'gs', 'language', 'len_ocr', 'len_gs'],
#         num_rows: 25258
#     })
# })

# %%
from transformers import AutoTokenizer

checkpoint = "google/mt5-small"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /Users/janneke/Library/Caches/pypoetry/virtualenvs/ocrpostcorrection-notebooks-avgggl3f-py3.9/lib/python3.9/site-packages/transformers/convert_slow_tokenizer.py:446: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
def preprocess_function(examples):
    inputs = [doc for doc in examples["ocr"]]
    model_inputs = tokenizer(inputs, max_length=500, truncation=True)

    labels = tokenizer(text_target=examples["gs"], max_length=500, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/85767 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9474 [00:00<?, ? examples/s]
# Map:   0%|          | 0/25258 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

# %%
from evaluate import load
cer = load("cer")

# %%
cer_score = cer.compute(predictions=val_data.ocr.to_list(), references=val_data.gs.to_list())
print(cer_score)
# Out:
# 0.21237264855586288

# %%
wer = load("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %%
wer_score = wer.compute(predictions=val_data.ocr.to_list(), references=val_data.gs.to_list())
print(wer_score)
# Out:
# 0.635085134039459

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Downloading generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="my_awesome_billsum_model",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=4,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=False,
    load_best_model_at_end="epoch",
    save_strategy="epoch",
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    # compute_metrics=compute_metrics,
)

# %%
trainer.train()

# %%
train_data.head()
# Out:
#               key  start_token_id  \
# 0  DE/DE4/204.txt               0
# 1  DE/DE4/204.txt              30
# 2  DE/DE4/204.txt              60
# 3  DE/DE4/204.txt              90
# 4  DE/DE4/204.txt             120
#
#                                                  ocr  \
# 0  annis ad nauigandum non—erant ufi. Has reficie...
# 1  milites aded fatebantur, ut Cn.Pompeii nomen i...
# 2  uidebatur,perpaucos de fum.— fionis initium na...
# 3  in fuga {pem falu— Pöpeii quiequam profe&um,qu...
# 4  Häc de— |== 297 Accipe,vide an placeat. Qnare ...
#
#                                                   gs language
# 0  annis ad nauigandum non erant uſi. Has reficie...       DE
# 1  milites adeò fatebantur, ut Cn. Pompeii nomen ...       DE
# 2  uidebatur, perpaucos de ſum-ſionis initium nat...       DE
# 3  in fuga ſpem ſalu-Põpeii quicquam profectum, q...       DE
# 4  Hãc de-27Accipe, vide an placeat. Quare ſic eu...       DE

# %%
train_data.loc[0].gs
# Out:
# 'annis ad nauigandum non erant uſi. Has reficiebant, illas Alexandriam re-ſtium tenebatur. Neque eum cõſilium ſuum fefellit, quin hoſtes eo prælioipſis: neq; illis imminẽtibus atq; inſequẽtibus ullus in naues receptus dare-ſe Torius ferebat: milites adeò fatebantur, ut Cn. Pompeii'

# %%
train_data.loc[1].gs
# Out:
# 'milites adeò fatebantur, ut Cn. Pompeii nomen in ſcutisNon dubitanter Alexandrini claſſem producunt, atque inſtruunt. In fronteauxilia, maioraq́; miſſurus exiſtimabatur. Quibus literis acceptis, inſolentipericlitarentur. Simul illud graue ac miſerum uidebatur, perpaucos de ſum-ſionis initium'

# %%
edlib.align(train_data.loc[0].gs, train_data.loc[1].gs, mode = "SHW")
# Out:
# {'editDistance': 205,
#  'alphabetLength': 41,
#  'locations': [(None, 227)],
#  'cigar': None}

# %%
train_data.loc[0].gs[222: 232]
# Out:
# 'ſe Torius '

# %%
edlib.getNiceAlignment(train_data.loc[0].gs, train_data.loc[1].gs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 edlib.getNiceAlignment(train_data.loc[0].gs, train_data.loc[1].gs)
#
# File edlib.pyx:158, in edlib.getNiceAlignment()
#
# TypeError: getNiceAlignment() takes at least 3 positional arguments (2 given)
